# %% [markdown]
# <a href="https://colab.research.google.com/github/rileytyh/NNDL-TransferLearning/blob/main/W4995_TransferLearning_Project_ConvNeXt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip Released_Data_NNDL_2025-20250510T140910Z-001.zip
# !unzip Released_Data_NNDL_2025/train_images.zip
# !unzip Released_Data_NNDL_2025/test_images.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: test_images/7677.jpg
#   inflating: __MACOSX/test_images/._7677.jpg
#   inflating: test_images/8544.jpg
#   inflating: __MACOSX/test_images/._8544.jpg
#   inflating: test_images/9882.jpg
#   inflating: __MACOSX/test_images/._9882.jpg
#   inflating: test_images/792.jpg
#   inflating: __MACOSX/test_images/._792.jpg
#   inflating: test_images/1206.jpg
#   inflating: __MACOSX/test_images/._1206.jpg
#   inflating: test_images/6569.jpg
#   inflating: __MACOSX/test_images/._6569.jpg
#   inflating: test_images/5060.jpg
#   inflating: __MACOSX/test_images/._5060.jpg
#   inflating: test_images/10248.jpg
#   inflating: __MACOSX/test_images/._10248.jpg
#   inflating: test_images/3411.jpg
#   inflating: __MACOSX/test_images/._3411.jpg
#   inflating: test_images/11156.jpg
#   inflating: __MACOSX/test_images/._11156.jpg
#   inflating: test_images/4418.jpg
#   inflating: __MACOSX/test_images/._4418.jpg
#   inflating: test_images/3377.jpg
#   inflating: __MACOSX/test_images/._3377.jpg
#   inflating: test_images/2069.jpg
#   inflating: __MACOSX/test_images/._2069.jpg
#   inflating: test_images/5706.jpg
#   inflating: __MACOSX/test_images/._5706.jpg
#   inflating: test_images/1560.jpg
#   inflating: __MACOSX/test_images/._1560.jpg
#   inflating: test_images/7111.jpg
#   inflating: __MACOSX/test_images/._7111.jpg
#   inflating: test_images/8222.jpg
#   inflating: __MACOSX/test_images/._8222.jpg
#   inflating: test_images/9128.jpg
#   inflating: __MACOSX/test_images/._9128.jpg
#   inflating: test_images/1574.jpg
#   inflating: __MACOSX/test_images/._1574.jpg
#   inflating: test_images/7105.jpg
#   inflating: __MACOSX/test_images/._7105.jpg
#   inflating: test_images/8236.jpg
#   inflating: __MACOSX/test_images/._8236.jpg
#   inflating: test_images/3363.jpg
#   inflating: __MACOSX/test_images/._3363.jpg
#   inflating: test_images/5712.jpg
#   inflating: __MACOSX/test_images/._5712.jpg
#   inflating: test_images/5074.jpg
#   inflating: __MACOSX/test_images/._5074.jpg
#   inflating: test_images/3405.jpg
#   inflating: __MACOSX/test_images/._3405.jpg
#   inflating: test_images/11142.jpg
#   inflating: __MACOSX/test_images/._11142.jpg
#   inflating: test_images/7663.jpg
#   inflating: __MACOSX/test_images/._7663.jpg
#   inflating: test_images/8550.jpg
#   inflating: __MACOSX/test_images/._8550.jpg
#   inflating: test_images/9896.jpg
#   inflating: __MACOSX/test_images/._9896.jpg
#   inflating: test_images/1212.jpg
#   inflating: __MACOSX/test_images/._1212.jpg
#   inflating: test_images/786.jpg
#   inflating: __MACOSX/test_images/._786.jpg
#   inflating: test_images/7850.jpg
#   inflating: __MACOSX/test_images/._7850.jpg
#   inflating: test_images/6596.jpg
#   inflating: __MACOSX/test_images/._6596.jpg
#   inflating: test_images/7688.jpg
#   inflating: __MACOSX/test_images/._7688.jpg
#   inflating: test_images/4381.jpg
#   inflating: __MACOSX/test_images/._4381.jpg
#   inflating: test_images/2928.jpg
#   inflating: __MACOSX/test_images/._2928.jpg
#   inflating: test_images/2096.jpg
#   inflating: __MACOSX/test_images/._2096.jpg
#   inflating: test_images/5921.jpg
#   inflating: __MACOSX/test_images/._5921.jpg
#   inflating: test_images/3388.jpg
#   inflating: __MACOSX/test_images/._3388.jpg
#   inflating: test_images/2082.jpg
#   inflating: __MACOSX/test_images/._2082.jpg
#   inflating: test_images/5935.jpg
#   inflating: __MACOSX/test_images/._5935.jpg
#   inflating: test_images/4395.jpg
#   inflating: __MACOSX/test_images/._4395.jpg
#   inflating: test_images/779.jpg
#   inflating: __MACOSX/test_images/._779.jpg
#   inflating: test_images/7844.jpg
#   inflating: __MACOSX/test_images/._7844.jpg
#   inflating: test_images/6582.jpg
#   inflating: __MACOSX/test_images/._6582.jpg
#   inflating: test_images/9869.jpg
#   inflating: __MACOSX/test_images/._9869.jpg
#   inflating: test_images/2914.jpg
#   inflating: __MACOSX/test_images/._2914.jpg
#   inflating: test_images/751.jpg
#   inflating: __MACOSX/test_images/._751.jpg
#   inflating: test_images/9699.jpg
#   inflating: __MACOSX/test_images/._9699.jpg
#   inflating: test_images/8587.jpg
#   inflating: __MACOSX/test_images/._8587.jpg
#   inflating: test_images/989.jpg
#   inflating: __MACOSX/test_images/._989.jpg
#   inflating: test_images/9841.jpg
#   inflating: __MACOSX/test_images/._9841.jpg
#   inflating: test_images/5909.jpg
#   inflating: __MACOSX/test_images/._5909.jpg
#   inflating: test_images/7878.jpg
#   inflating: __MACOSX/test_images/._7878.jpg
#   inflating: test_images/745.jpg
#   inflating: __MACOSX/test_images/._745.jpg
#   inflating: test_images/8593.jpg
#   inflating: __MACOSX/test_images/._8593.jpg
#   inflating: test_images/9855.jpg
#   inflating: __MACOSX/test_images/._9855.jpg
#   inflating: test_images/2900.jpg
#   inflating: __MACOSX/test_images/._2900.jpg
#   inflating: test_images/5908.jpg
#   inflating: __MACOSX/test_images/._5908.jpg
#   inflating: test_images/2901.jpg
#   inflating: __MACOSX/test_images/._2901.jpg
#   inflating: test_images/9854.jpg
#   inflating: __MACOSX/test_images/._9854.jpg
#   inflating: test_images/8592.jpg
#   inflating: __MACOSX/test_images/._8592.jpg
#   inflating: test_images/744.jpg
#   inflating: __MACOSX/test_images/._744.jpg
#   inflating: test_images/7879.jpg
#   inflating: __MACOSX/test_images/._7879.jpg
#   inflating: test_images/9840.jpg
#   inflating: __MACOSX/test_images/._9840.jpg
#   inflating: test_images/8586.jpg
#   inflating: __MACOSX/test_images/._8586.jpg
#   inflating: test_images/988.jpg
#   inflating: __MACOSX/test_images/._988.jpg
#   inflating: test_images/9698.jpg
#   inflating: __MACOSX/test_images/._9698.jpg
#   inflating: test_images/750.jpg
#   inflating: __MACOSX/test_images/._750.jpg
#   inflating: test_images/2915.jpg
#   inflating: __MACOSX/test_images/._2915.jpg
#   inflating: test_images/5934.jpg
#   inflating: __MACOSX/test_images/._5934.jpg
#   inflating: test_images/2083.jpg
#   inflating: __MACOSX/test_images/._2083.jpg
#   inflating: test_images/9868.jpg
#   inflating: __MACOSX/test_images/._9868.jpg
#   inflating: test_images/6583.jpg
#   inflating: __MACOSX/test_images/._6583.jpg
#   inflating: test_images/7845.jpg
#   inflating: __MACOSX/test_images/._7845.jpg
#   inflating: test_images/778.jpg
#   inflating: __MACOSX/test_images/._778.jpg
#   inflating: test_images/4394.jpg
#   inflating: __MACOSX/test_images/._4394.jpg
#   inflating: test_images/2929.jpg
#   inflating: __MACOSX/test_images/._2929.jpg
#   inflating: test_images/4380.jpg
#   inflating: __MACOSX/test_images/._4380.jpg
#   inflating: test_images/7689.jpg
#   inflating: __MACOSX/test_images/._7689.jpg
#   inflating: test_images/6597.jpg
#   inflating: __MACOSX/test_images/._6597.jpg
#   inflating: test_images/7851.jpg
#   inflating: __MACOSX/test_images/._7851.jpg
#   inflating: test_images/3389.jpg
#   inflating: __MACOSX/test_images/._3389.jpg
#   inflating: test_images/5920.jpg
#   inflating: __MACOSX/test_images/._5920.jpg
#   inflating: test_images/2097.jpg
#   inflating: __MACOSX/test_images/._2097.jpg
#   inflating: test_images/5713.jpg
#   inflating: __MACOSX/test_images/._5713.jpg
#   inflating: test_images/3362.jpg
#   inflating: __MACOSX/test_images/._3362.jpg
#   inflating: test_images/8237.jpg
#   inflating: __MACOSX/test_images/._8237.jpg
#   inflating: test_images/7104.jpg
#   inflating: __MACOSX/test_images/._7104.jpg
#   inflating: test_images/1575.jpg
#   inflating: __MACOSX/test_images/._1575.jpg
#   inflating: test_images/9129.jpg
#   inflating: __MACOSX/test_images/._9129.jpg
#   inflating: test_images/787.jpg
#   inflating: __MACOSX/test_images/._787.jpg
#   inflating: test_images/1213.jpg
#   inflating: __MACOSX/test_images/._1213.jpg
#   inflating: test_images/9897.jpg
#   inflating: __MACOSX/test_images/._9897.jpg
#   inflating: test_images/8551.jpg
#   inflating: __MACOSX/test_images/._8551.jpg
#   inflating: test_images/7662.jpg
#   inflating: __MACOSX/test_images/._7662.jpg
#   inflating: test_images/11143.jpg
#   inflating: __MACOSX/test_images/._11143.jpg
#   inflating: test_images/3404.jpg
#   inflating: __MACOSX/test_images/._3404.jpg
#   inflating: test_images/5075.jpg
#   inflating: __MACOSX/test_images/._5075.jpg
#   inflating: test_images/11157.jpg
#   inflating: __MACOSX/test_images/._11157.jpg
#   inflating: test_images/3410.jpg
#   inflating: __MACOSX/test_images/._3410.jpg
#   inflating: test_images/10249.jpg
#   inflating: __MACOSX/test_images/._10249.jpg
#   inflating: test_images/5061.jpg
#   inflating: __MACOSX/test_images/._5061.jpg
#   inflating: test_images/6568.jpg
#   inflating: __MACOSX/test_images/._6568.jpg
#   inflating: test_images/1207.jpg
#   inflating: __MACOSX/test_images/._1207.jpg
#   inflating: test_images/793.jpg
#   inflating: __MACOSX/test_images/._793.jpg
#   inflating: test_images/9883.jpg
#   inflating: __MACOSX/test_images/._9883.jpg
#   inflating: test_images/8545.jpg
#   inflating: __MACOSX/test_images/._8545.jpg
#   inflating: test_images/7676.jpg
#   inflating: __MACOSX/test_images/._7676.jpg
#   inflating: test_images/8223.jpg
#   inflating: __MACOSX/test_images/._8223.jpg
#   inflating: test_images/7110.jpg
#   inflating: __MACOSX/test_images/._7110.jpg
#   inflating: test_images/1561.jpg
#   inflating: __MACOSX/test_images/._1561.jpg
#   inflating: test_images/5707.jpg
#   inflating: __MACOSX/test_images/._5707.jpg
#   inflating: test_images/2068.jpg
#   inflating: __MACOSX/test_images/._2068.jpg
#   inflating: test_images/3376.jpg
#   inflating: __MACOSX/test_images/._3376.jpg
#   inflating: test_images/4419.jpg
#   inflating: __MACOSX/test_images/._4419.jpg
#   inflating: test_images/7138.jpg
#   inflating: __MACOSX/test_images/._7138.jpg
#   inflating: test_images/1549.jpg
#   inflating: __MACOSX/test_images/._1549.jpg
#   inflating: test_images/6226.jpg
#   inflating: __MACOSX/test_images/._6226.jpg
#   inflating: test_images/9115.jpg
#   inflating: __MACOSX/test_images/._9115.jpg
#   inflating: test_images/2040.jpg
#   inflating: __MACOSX/test_images/._2040.jpg
#   inflating: test_images/10507.jpg
#   inflating: __MACOSX/test_images/._10507.jpg
#   inflating: test_images/4431.jpg
#   inflating: __MACOSX/test_images/._4431.jpg
#   inflating: test_images/4357.jpg
#   inflating: __MACOSX/test_images/._4357.jpg
#   inflating: test_images/3438.jpg
#   inflating: __MACOSX/test_images/._3438.jpg
#   inflating: test_images/2726.jpg
#   inflating: __MACOSX/test_images/._2726.jpg
#   inflating: test_images/10261.jpg
#   inflating: __MACOSX/test_images/._10261.jpg
#   inflating: test_images/5049.jpg
#   inflating: __MACOSX/test_images/._5049.jpg
#   inflating: test_images/6540.jpg
#   inflating: __MACOSX/test_images/._6540.jpg
#   inflating: test_images/9673.jpg
#   inflating: __MACOSX/test_images/._9673.jpg
#   inflating: test_images/7886.jpg
#   inflating: __MACOSX/test_images/._7886.jpg
#   inflating: test_images/963.jpg
#   inflating: __MACOSX/test_images/._963.jpg
#   inflating: test_images/6554.jpg
#   inflating: __MACOSX/test_images/._6554.jpg
#   inflating: test_images/9667.jpg
#   inflating: __MACOSX/test_images/._9667.jpg
#   inflating: test_images/7892.jpg
#   inflating: __MACOSX/test_images/._7892.jpg
#   inflating: test_images/977.jpg
#   inflating: __MACOSX/test_images/._977.jpg
#   inflating: test_images/8579.jpg
#   inflating: __MACOSX/test_images/._8579.jpg
#   inflating: test_images/4343.jpg
#   inflating: __MACOSX/test_images/._4343.jpg
#   inflating: test_images/2732.jpg
#   inflating: __MACOSX/test_images/._2732.jpg
#   inflating: test_images/10275.jpg
#   inflating: __MACOSX/test_images/._10275.jpg
#   inflating: test_images/2054.jpg
#   inflating: __MACOSX/test_images/._2054.jpg
#   inflating: test_images/10513.jpg
#   inflating: __MACOSX/test_images/._10513.jpg
#   inflating: test_images/4425.jpg
#   inflating: __MACOSX/test_images/._4425.jpg
#   inflating: test_images/6232.jpg
#   inflating: __MACOSX/test_images/._6232.jpg
#   inflating: test_images/9101.jpg
#   inflating: __MACOSX/test_images/._9101.jpg
#   inflating: test_images/8948.jpg
#   inflating: __MACOSX/test_images/._8948.jpg
#   inflating: test_images/546.jpg
#   inflating: __MACOSX/test_images/._546.jpg
#   inflating: test_images/8790.jpg
#   inflating: __MACOSX/test_images/._8790.jpg
#   inflating: test_images/6965.jpg
#   inflating: __MACOSX/test_images/._6965.jpg
#   inflating: test_images/4814.jpg
#   inflating: __MACOSX/test_images/._4814.jpg
#   inflating: test_images/10922.jpg
#   inflating: __MACOSX/test_images/._10922.jpg
#   inflating: test_images/220.jpg
#   inflating: __MACOSX/test_images/._220.jpg
#   inflating: test_images/1978.jpg
#   inflating: __MACOSX/test_images/._1978.jpg
#   inflating: test_images/234.jpg
#   inflating: __MACOSX/test_images/._234.jpg
#   inflating: test_images/4800.jpg
#   inflating: __MACOSX/test_images/._4800.jpg
#   inflating: test_images/10936.jpg
#   inflating: __MACOSX/test_images/._10936.jpg
#   inflating: test_images/3809.jpg
#   inflating: __MACOSX/test_images/._3809.jpg
#   inflating: test_images/10088.jpg
#   inflating: __MACOSX/test_images/._10088.jpg
#   inflating: test_images/552.jpg
#   inflating: __MACOSX/test_images/._552.jpg
#   inflating: test_images/8784.jpg
#   inflating: __MACOSX/test_images/._8784.jpg
#   inflating: test_images/6971.jpg
#   inflating: __MACOSX/test_images/._6971.jpg
#   inflating: test_images/4196.jpg
#   inflating: __MACOSX/test_images/._4196.jpg
#   inflating: test_images/5288.jpg
#   inflating: __MACOSX/test_images/._5288.jpg
#   inflating: test_images/3821.jpg
#   inflating: __MACOSX/test_images/._3821.jpg
#   inflating: test_images/8974.jpg
#   inflating: __MACOSX/test_images/._8974.jpg
#   inflating: test_images/6781.jpg
#   inflating: __MACOSX/test_images/._6781.jpg
#   inflating: test_images/6959.jpg
#   inflating: __MACOSX/test_images/._6959.jpg
#   inflating: test_images/1950.jpg
#   inflating: __MACOSX/test_images/._1950.jpg
#   inflating: test_images/1788.jpg
#   inflating: __MACOSX/test_images/._1788.jpg
#   inflating: test_images/4828.jpg
#   inflating: __MACOSX/test_images/._4828.jpg
#   inflating: test_images/2281.jpg
#   inflating: __MACOSX/test_images/._2281.jpg
#   inflating: test_images/2295.jpg
#   inflating: __MACOSX/test_images/._2295.jpg
#   inflating: test_images/1944.jpg
#   inflating: __MACOSX/test_images/._1944.jpg
#   inflating: test_images/208.jpg
#   inflating: __MACOSX/test_images/._208.jpg
#   inflating: test_images/8960.jpg
#   inflating: __MACOSX/test_images/._8960.jpg
#   inflating: test_images/6795.jpg
#   inflating: __MACOSX/test_images/._6795.jpg
#   inflating: test_images/4182.jpg
#   inflating: __MACOSX/test_images/._4182.jpg
#   inflating: test_images/3835.jpg
#   inflating: __MACOSX/test_images/._3835.jpg
#   inflating: test_images/5277.jpg
#   inflating: __MACOSX/test_images/._5277.jpg
#   inflating: test_images/2518.jpg
#   inflating: __MACOSX/test_images/._2518.jpg
#   inflating: test_images/3606.jpg
#   inflating: __MACOSX/test_images/._3606.jpg
#   inflating: test_images/4169.jpg
#   inflating: __MACOSX/test_images/._4169.jpg
#   inflating: test_images/7460.jpg
#   inflating: __MACOSX/test_images/._7460.jpg
#   inflating: test_images/8753.jpg
#   inflating: __MACOSX/test_images/._8753.jpg
#   inflating: test_images/1011.jpg
#   inflating: __MACOSX/test_images/._1011.jpg
#   inflating: test_images/585.jpg
#   inflating: __MACOSX/test_images/._585.jpg
#   inflating: test_images/6018.jpg
#   inflating: __MACOSX/test_images/._6018.jpg
#   inflating: test_images/1777.jpg
#   inflating: __MACOSX/test_images/._1777.jpg
#   inflating: test_images/7306.jpg
#   inflating: __MACOSX/test_images/._7306.jpg
#   inflating: test_images/8035.jpg
#   inflating: __MACOSX/test_images/._8035.jpg
#   inflating: test_images/3160.jpg
#   inflating: __MACOSX/test_images/._3160.jpg
#   inflating: test_images/10739.jpg
#   inflating: __MACOSX/test_images/._10739.jpg
#   inflating: test_images/5511.jpg
#   inflating: __MACOSX/test_images/._5511.jpg
#   inflating: test_images/3174.jpg
#   inflating: __MACOSX/test_images/._3174.jpg
#   inflating: test_images/5505.jpg
#   inflating: __MACOSX/test_images/._5505.jpg
#   inflating: test_images/1763.jpg
#   inflating: __MACOSX/test_images/._1763.jpg
#   inflating: test_images/7312.jpg
#   inflating: __MACOSX/test_images/._7312.jpg
#   inflating: test_images/8021.jpg
#   inflating: __MACOSX/test_images/._8021.jpg
#   inflating: test_images/7474.jpg
#   inflating: __MACOSX/test_images/._7474.jpg
#   inflating: test_images/8747.jpg
#   inflating: __MACOSX/test_images/._8747.jpg
#   inflating: test_images/591.jpg
#   inflating: __MACOSX/test_images/._591.jpg
#   inflating: test_images/1005.jpg
#   inflating: __MACOSX/test_images/._1005.jpg
#   inflating: test_images/9459.jpg
#   inflating: __MACOSX/test_images/._9459.jpg
#   inflating: test_images/5263.jpg
#   inflating: __MACOSX/test_images/._5263.jpg
#   inflating: test_images/3612.jpg
#   inflating: __MACOSX/test_images/._3612.jpg
#   inflating: test_images/9471.jpg
#   inflating: __MACOSX/test_images/._9471.jpg
#   inflating: test_images/6742.jpg
#   inflating: __MACOSX/test_images/._6742.jpg
#   inflating: test_images/10063.jpg
#   inflating: __MACOSX/test_images/._10063.jpg
#   inflating: test_images/2524.jpg
#   inflating: __MACOSX/test_images/._2524.jpg
#   inflating: test_images/4155.jpg
#   inflating: __MACOSX/test_images/._4155.jpg
#   inflating: test_images/4633.jpg
#   inflating: __MACOSX/test_images/._4633.jpg
#   inflating: test_images/10705.jpg
#   inflating: __MACOSX/test_images/._10705.jpg
#   inflating: test_images/2242.jpg
#   inflating: __MACOSX/test_images/._2242.jpg
#   inflating: test_images/9317.jpg
#   inflating: __MACOSX/test_images/._9317.jpg
#   inflating: test_images/6024.jpg
#   inflating: __MACOSX/test_images/._6024.jpg
#   inflating: test_images/1993.jpg
#   inflating: __MACOSX/test_images/._1993.jpg
#   inflating: test_images/8009.jpg
#   inflating: __MACOSX/test_images/._8009.jpg
#   inflating: test_images/9303.jpg
#   inflating: __MACOSX/test_images/._9303.jpg
#   inflating: test_images/6030.jpg
#   inflating: __MACOSX/test_images/._6030.jpg
#   inflating: test_images/1987.jpg
#   inflating: __MACOSX/test_images/._1987.jpg
#   inflating: test_images/4627.jpg
#   inflating: __MACOSX/test_images/._4627.jpg
#   inflating: test_images/3148.jpg
#   inflating: __MACOSX/test_images/._3148.jpg
#   inflating: test_images/10711.jpg
#   inflating: __MACOSX/test_images/._10711.jpg
#   inflating: test_images/2256.jpg
#   inflating: __MACOSX/test_images/._2256.jpg
#   inflating: test_images/5539.jpg
#   inflating: __MACOSX/test_images/._5539.jpg
#   inflating: test_images/10077.jpg
#   inflating: __MACOSX/test_images/._10077.jpg
#   inflating: test_images/2530.jpg
#   inflating: __MACOSX/test_images/._2530.jpg
#   inflating: test_images/4141.jpg
#   inflating: __MACOSX/test_images/._4141.jpg
#   inflating: test_images/7448.jpg
#   inflating: __MACOSX/test_images/._7448.jpg
#   inflating: test_images/1039.jpg
#   inflating: __MACOSX/test_images/._1039.jpg
#   inflating: test_images/9465.jpg
#   inflating: __MACOSX/test_images/._9465.jpg
#   inflating: test_images/6756.jpg
#   inflating: __MACOSX/test_images/._6756.jpg
#   inflating: test_images/6811.jpg
#   inflating: __MACOSX/test_images/._6811.jpg
#   inflating: test_images/432.jpg
#   inflating: __MACOSX/test_images/._432.jpg
#   inflating: test_images/3969.jpg
#   inflating: __MACOSX/test_images/._3969.jpg
#   inflating: test_images/10856.jpg
#   inflating: __MACOSX/test_images/._10856.jpg
#   inflating: test_images/4960.jpg
#   inflating: __MACOSX/test_images/._4960.jpg
#   inflating: test_images/354.jpg
#   inflating: __MACOSX/test_images/._354.jpg
#   inflating: test_images/1818.jpg
#   inflating: __MACOSX/test_images/._1818.jpg
#   inflating: test_images/8182.jpg
#   inflating: __MACOSX/test_images/._8182.jpg
#   inflating: test_images/340.jpg
#   inflating: __MACOSX/test_images/._340.jpg
#   inflating: test_images/9288.jpg
#   inflating: __MACOSX/test_images/._9288.jpg
#   inflating: test_images/8196.jpg
#   inflating: __MACOSX/test_images/._8196.jpg
#   inflating: test_images/10842.jpg
#   inflating: __MACOSX/test_images/._10842.jpg
#   inflating: test_images/4974.jpg
#   inflating: __MACOSX/test_images/._4974.jpg
#   inflating: test_images/6805.jpg
#   inflating: __MACOSX/test_images/._6805.jpg
#   inflating: test_images/8828.jpg
#   inflating: __MACOSX/test_images/._8828.jpg
#   inflating: test_images/426.jpg
#   inflating: __MACOSX/test_images/._426.jpg
#   inflating: test_images/2493.jpg
#   inflating: __MACOSX/test_images/._2493.jpg
#   inflating: test_images/3955.jpg
#   inflating: __MACOSX/test_images/._3955.jpg
#   inflating: test_images/8800.jpg
#   inflating: __MACOSX/test_images/._8800.jpg
#   inflating: test_images/368.jpg
#   inflating: __MACOSX/test_images/._368.jpg
#   inflating: test_images/6193.jpg
#   inflating: __MACOSX/test_images/._6193.jpg
#   inflating: test_images/1824.jpg
#   inflating: __MACOSX/test_images/._1824.jpg
#   inflating: test_images/4784.jpg
#   inflating: __MACOSX/test_images/._4784.jpg
#   inflating: test_images/4790.jpg
#   inflating: __MACOSX/test_images/._4790.jpg
#   inflating: test_images/4948.jpg
#   inflating: __MACOSX/test_images/._4948.jpg
#   inflating: test_images/6187.jpg
#   inflating: __MACOSX/test_images/._6187.jpg
#   inflating: test_images/1830.jpg
#   inflating: __MACOSX/test_images/._1830.jpg
#   inflating: test_images/7299.jpg
#   inflating: __MACOSX/test_images/._7299.jpg
#   inflating: test_images/6839.jpg
#   inflating: __MACOSX/test_images/._6839.jpg
#   inflating: test_images/8814.jpg
#   inflating: __MACOSX/test_images/._8814.jpg
#   inflating: test_images/2487.jpg
#   inflating: __MACOSX/test_images/._2487.jpg
#   inflating: test_images/3941.jpg
#   inflating: __MACOSX/test_images/._3941.jpg
#   inflating: test_images/3799.jpg
#   inflating: __MACOSX/test_images/._3799.jpg
#   inflating: test_images/3772.jpg
#   inflating: __MACOSX/test_images/._3772.jpg
#   inflating: test_images/5303.jpg
#   inflating: __MACOSX/test_images/._5303.jpg
#   inflating: test_images/9539.jpg
#   inflating: __MACOSX/test_images/._9539.jpg
#   inflating: test_images/1165.jpg
#   inflating: __MACOSX/test_images/._1165.jpg
#   inflating: test_images/7514.jpg
#   inflating: __MACOSX/test_images/._7514.jpg
#   inflating: test_images/8627.jpg
#   inflating: __MACOSX/test_images/._8627.jpg
#   inflating: test_images/7272.jpg
#   inflating: __MACOSX/test_images/._7272.jpg
#   inflating: test_images/8141.jpg
#   inflating: __MACOSX/test_images/._8141.jpg
#   inflating: test_images/1603.jpg
#   inflating: __MACOSX/test_images/._1603.jpg
#   inflating: test_images/397.jpg
#   inflating: __MACOSX/test_images/._397.jpg
#   inflating: test_images/5465.jpg
#   inflating: __MACOSX/test_images/._5465.jpg
#   inflating: test_images/3014.jpg
#   inflating: __MACOSX/test_images/._3014.jpg
#   inflating: test_images/10895.jpg
#   inflating: __MACOSX/test_images/._10895.jpg
#   inflating: test_images/5471.jpg
#   inflating: __MACOSX/test_images/._5471.jpg
#   inflating: test_images/10659.jpg
#   inflating: __MACOSX/test_images/._10659.jpg
#   inflating: test_images/3000.jpg
#   inflating: __MACOSX/test_images/._3000.jpg
#   inflating: test_images/10881.jpg
#   inflating: __MACOSX/test_images/._10881.jpg
#   inflating: test_images/7266.jpg
#   inflating: __MACOSX/test_images/._7266.jpg
#   inflating: test_images/8155.jpg
#   inflating: __MACOSX/test_images/._8155.jpg
#   inflating: test_images/383.jpg
#   inflating: __MACOSX/test_images/._383.jpg
#   inflating: test_images/1617.jpg
#   inflating: __MACOSX/test_images/._1617.jpg
#   inflating: test_images/6178.jpg
#   inflating: __MACOSX/test_images/._6178.jpg
#   inflating: test_images/1171.jpg
#   inflating: __MACOSX/test_images/._1171.jpg
#   inflating: test_images/7500.jpg
#   inflating: __MACOSX/test_images/._7500.jpg
#   inflating: test_images/8633.jpg
#   inflating: __MACOSX/test_images/._8633.jpg
#   inflating: test_images/4009.jpg
#   inflating: __MACOSX/test_images/._4009.jpg
#   inflating: test_images/3766.jpg
#   inflating: __MACOSX/test_images/._3766.jpg
#   inflating: test_images/2478.jpg
#   inflating: __MACOSX/test_images/._2478.jpg
#   inflating: test_images/5317.jpg
#   inflating: __MACOSX/test_images/._5317.jpg
#   inflating: test_images/9505.jpg
#   inflating: __MACOSX/test_images/._9505.jpg
#   inflating: test_images/6636.jpg
#   inflating: __MACOSX/test_images/._6636.jpg
#   inflating: test_images/1159.jpg
#   inflating: __MACOSX/test_images/._1159.jpg
#   inflating: test_images/7528.jpg
#   inflating: __MACOSX/test_images/._7528.jpg
#   inflating: test_images/4021.jpg
#   inflating: __MACOSX/test_images/._4021.jpg
#   inflating: test_images/10117.jpg
#   inflating: __MACOSX/test_images/._10117.jpg
#   inflating: test_images/2450.jpg
#   inflating: __MACOSX/test_images/._2450.jpg
#   inflating: test_images/3996.jpg
#   inflating: __MACOSX/test_images/._3996.jpg
#   inflating: test_images/5459.jpg
#   inflating: __MACOSX/test_images/._5459.jpg
#   inflating: test_images/10671.jpg
#   inflating: __MACOSX/test_images/._10671.jpg
#   inflating: test_images/2336.jpg
#   inflating: __MACOSX/test_images/._2336.jpg
#   inflating: test_images/3028.jpg
#   inflating: __MACOSX/test_images/._3028.jpg
#   inflating: test_images/4747.jpg
#   inflating: __MACOSX/test_images/._4747.jpg
#   inflating: test_images/9263.jpg
#   inflating: __MACOSX/test_images/._9263.jpg
#   inflating: test_images/6150.jpg
#   inflating: __MACOSX/test_images/._6150.jpg
#   inflating: test_images/8169.jpg
#   inflating: __MACOSX/test_images/._8169.jpg
#   inflating: test_images/9277.jpg
#   inflating: __MACOSX/test_images/._9277.jpg
#   inflating: test_images/6144.jpg
#   inflating: __MACOSX/test_images/._6144.jpg
#   inflating: test_images/10665.jpg
#   inflating: __MACOSX/test_images/._10665.jpg
#   inflating: test_images/2322.jpg
#   inflating: __MACOSX/test_images/._2322.jpg
#   inflating: test_images/4753.jpg
#   inflating: __MACOSX/test_images/._4753.jpg
#   inflating: test_images/4035.jpg
#   inflating: __MACOSX/test_images/._4035.jpg
#   inflating: test_images/10103.jpg
#   inflating: __MACOSX/test_images/._10103.jpg
#   inflating: test_images/2444.jpg
#   inflating: __MACOSX/test_images/._2444.jpg
#   inflating: test_images/3982.jpg
#   inflating: __MACOSX/test_images/._3982.jpg
#   inflating: test_images/9511.jpg
#   inflating: __MACOSX/test_images/._9511.jpg
#   inflating: test_images/6622.jpg
#   inflating: __MACOSX/test_images/._6622.jpg
#   inflating: test_images/8380.jpg
#   inflating: __MACOSX/test_images/._8380.jpg
#   inflating: test_images/156.jpg
#   inflating: __MACOSX/test_images/._156.jpg
#   inflating: test_images/2875.jpg
#   inflating: __MACOSX/test_images/._2875.jpg
#   inflating: test_images/630.jpg
#   inflating: __MACOSX/test_images/._630.jpg
#   inflating: test_images/9920.jpg
#   inflating: __MACOSX/test_images/._9920.jpg
#   inflating: test_images/624.jpg
#   inflating: __MACOSX/test_images/._624.jpg
#   inflating: test_images/7919.jpg
#   inflating: __MACOSX/test_images/._7919.jpg
#   inflating: test_images/9934.jpg
#   inflating: __MACOSX/test_images/._9934.jpg
#   inflating: test_images/2861.jpg
#   inflating: __MACOSX/test_images/._2861.jpg
#   inflating: test_images/10498.jpg
#   inflating: __MACOSX/test_images/._10498.jpg
#   inflating: test_images/5868.jpg
#   inflating: __MACOSX/test_images/._5868.jpg
#   inflating: test_images/8394.jpg
#   inflating: __MACOSX/test_images/._8394.jpg
#   inflating: test_images/142.jpg
#   inflating: __MACOSX/test_images/._142.jpg
#   inflating: test_images/5698.jpg
#   inflating: __MACOSX/test_images/._5698.jpg
#   inflating: test_images/4586.jpg
#   inflating: __MACOSX/test_images/._4586.jpg
#   inflating: test_images/5840.jpg
#   inflating: __MACOSX/test_images/._5840.jpg
#   inflating: test_images/6391.jpg
#   inflating: __MACOSX/test_images/._6391.jpg
#   inflating: test_images/7931.jpg
#   inflating: __MACOSX/test_images/._7931.jpg
#   inflating: test_images/1398.jpg
#   inflating: __MACOSX/test_images/._1398.jpg
#   inflating: test_images/94.jpg
#   inflating: __MACOSX/test_images/._94.jpg
#   inflating: test_images/2849.jpg
#   inflating: __MACOSX/test_images/._2849.jpg
#   inflating: test_images/2691.jpg
#   inflating: __MACOSX/test_images/._2691.jpg
#   inflating: test_images/2685.jpg
#   inflating: __MACOSX/test_images/._2685.jpg
#   inflating: test_images/7925.jpg
#   inflating: __MACOSX/test_images/._7925.jpg
#   inflating: test_images/618.jpg
#   inflating: __MACOSX/test_images/._618.jpg
#   inflating: test_images/80.jpg
#   inflating: __MACOSX/test_images/._80.jpg
#   inflating: test_images/9908.jpg
#   inflating: __MACOSX/test_images/._9908.jpg
#   inflating: test_images/6385.jpg
#   inflating: __MACOSX/test_images/._6385.jpg
#   inflating: test_images/4592.jpg
#   inflating: __MACOSX/test_images/._4592.jpg
#   inflating: test_images/5854.jpg
#   inflating: __MACOSX/test_images/._5854.jpg
#   inflating: test_images/4579.jpg
#   inflating: __MACOSX/test_images/._4579.jpg
#   inflating: test_images/3216.jpg
#   inflating: __MACOSX/test_images/._3216.jpg
#   inflating: test_images/2108.jpg
#   inflating: __MACOSX/test_images/._2108.jpg
#   inflating: test_images/5667.jpg
#   inflating: __MACOSX/test_images/._5667.jpg
#   inflating: test_images/195.jpg
#   inflating: __MACOSX/test_images/._195.jpg
#   inflating: test_images/1401.jpg
#   inflating: __MACOSX/test_images/._1401.jpg
#   inflating: test_images/8343.jpg
#   inflating: __MACOSX/test_images/._8343.jpg
#   inflating: test_images/7070.jpg
#   inflating: __MACOSX/test_images/._7070.jpg
#   inflating: test_images/8425.jpg
#   inflating: __MACOSX/test_images/._8425.jpg
#   inflating: test_images/7716.jpg
#   inflating: __MACOSX/test_images/._7716.jpg
#   inflating: test_images/1367.jpg
#   inflating: __MACOSX/test_images/._1367.jpg
#   inflating: test_images/6408.jpg
#   inflating: __MACOSX/test_images/._6408.jpg
#   inflating: test_images/5101.jpg
#   inflating: __MACOSX/test_images/._5101.jpg
#   inflating: test_images/10329.jpg
#   inflating: __MACOSX/test_images/._10329.jpg
#   inflating: test_images/11037.jpg
#   inflating: __MACOSX/test_images/._11037.jpg
#   inflating: test_images/3570.jpg
#   inflating: __MACOSX/test_images/._3570.jpg
#   inflating: test_images/5115.jpg
#   inflating: __MACOSX/test_images/._5115.jpg
#   inflating: test_images/11023.jpg
#   inflating: __MACOSX/test_images/._11023.jpg
#   inflating: test_images/3564.jpg
#   inflating: __MACOSX/test_images/._3564.jpg
#   inflating: test_images/8431.jpg
#   inflating: __MACOSX/test_images/._8431.jpg
#   inflating: test_images/7702.jpg
#   inflating: __MACOSX/test_images/._7702.jpg
#   inflating: test_images/1373.jpg
#   inflating: __MACOSX/test_images/._1373.jpg
#   inflating: test_images/9049.jpg
#   inflating: __MACOSX/test_images/._9049.jpg
#   inflating: test_images/1415.jpg
#   inflating: __MACOSX/test_images/._1415.jpg
#   inflating: test_images/181.jpg
#   inflating: __MACOSX/test_images/._181.jpg
#   inflating: test_images/8357.jpg
#   inflating: __MACOSX/test_images/._8357.jpg
#   inflating: test_images/7064.jpg
#   inflating: __MACOSX/test_images/._7064.jpg
#   inflating: test_images/3202.jpg
#   inflating: __MACOSX/test_images/._3202.jpg
#   inflating: test_images/5673.jpg
#   inflating: __MACOSX/test_images/._5673.jpg
#   inflating: test_images/6352.jpg
#   inflating: __MACOSX/test_images/._6352.jpg
#   inflating: test_images/9061.jpg
#   inflating: __MACOSX/test_images/._9061.jpg
#   inflating: test_images/4545.jpg
#   inflating: __MACOSX/test_images/._4545.jpg
#   inflating: test_images/5883.jpg
#   inflating: __MACOSX/test_images/._5883.jpg
#   inflating: test_images/5.jpg
#   inflating: __MACOSX/test_images/._5.jpg
#   inflating: test_images/2134.jpg
#   inflating: __MACOSX/test_images/._2134.jpg
#   inflating: test_images/10473.jpg
#   inflating: __MACOSX/test_images/._10473.jpg
#   inflating: test_images/2652.jpg
#   inflating: __MACOSX/test_images/._2652.jpg
#   inflating: test_images/10315.jpg
#   inflating: __MACOSX/test_images/._10315.jpg
#   inflating: test_images/4223.jpg
#   inflating: __MACOSX/test_images/._4223.jpg
#   inflating: test_images/817.jpg
#   inflating: __MACOSX/test_images/._817.jpg
#   inflating: test_images/8419.jpg
#   inflating: __MACOSX/test_images/._8419.jpg
#   inflating: test_images/57.jpg
#   inflating: __MACOSX/test_images/._57.jpg
#   inflating: test_images/6434.jpg
#   inflating: __MACOSX/test_images/._6434.jpg
#   inflating: test_images/9707.jpg
#   inflating: __MACOSX/test_images/._9707.jpg
#   inflating: test_images/803.jpg
#   inflating: __MACOSX/test_images/._803.jpg
#   inflating: test_images/6420.jpg
#   inflating: __MACOSX/test_images/._6420.jpg
#   inflating: test_images/43.jpg
#   inflating: __MACOSX/test_images/._43.jpg
#   inflating: test_images/9713.jpg
#   inflating: __MACOSX/test_images/._9713.jpg
#   inflating: test_images/5129.jpg
#   inflating: __MACOSX/test_images/._5129.jpg
#   inflating: test_images/2646.jpg
#   inflating: __MACOSX/test_images/._2646.jpg
#   inflating: test_images/10301.jpg
#   inflating: __MACOSX/test_images/._10301.jpg
#   inflating: test_images/3558.jpg
#   inflating: __MACOSX/test_images/._3558.jpg
#   inflating: test_images/4237.jpg
#   inflating: __MACOSX/test_images/._4237.jpg
#   inflating: test_images/4551.jpg
#   inflating: __MACOSX/test_images/._4551.jpg
#   inflating: test_images/5897.jpg
#   inflating: __MACOSX/test_images/._5897.jpg
#   inflating: test_images/2120.jpg
#   inflating: __MACOSX/test_images/._2120.jpg
#   inflating: test_images/10467.jpg
#   inflating: __MACOSX/test_images/._10467.jpg
#   inflating: test_images/6346.jpg
#   inflating: __MACOSX/test_images/._6346.jpg
#   inflating: test_images/9075.jpg
#   inflating: __MACOSX/test_images/._9075.jpg
#   inflating: test_images/1429.jpg
#   inflating: __MACOSX/test_images/._1429.jpg
#   inflating: test_images/7058.jpg
#   inflating: __MACOSX/test_images/._7058.jpg
#   inflating: test_images/6436.jpg
#   inflating: __MACOSX/test_images/._6436.jpg
#   inflating: test_images/55.jpg
#   inflating: __MACOSX/test_images/._55.jpg
#   inflating: test_images/9705.jpg
#   inflating: __MACOSX/test_images/._9705.jpg
#   inflating: test_images/1359.jpg
#   inflating: __MACOSX/test_images/._1359.jpg
#   inflating: test_images/7728.jpg
#   inflating: __MACOSX/test_images/._7728.jpg
#   inflating: test_images/815.jpg
#   inflating: __MACOSX/test_images/._815.jpg
#   inflating: test_images/2888.jpg
#   inflating: __MACOSX/test_images/._2888.jpg
#   inflating: test_images/4221.jpg
#   inflating: __MACOSX/test_images/._4221.jpg
#   inflating: test_images/11009.jpg
#   inflating: __MACOSX/test_images/._11009.jpg
#   inflating: test_images/2650.jpg
#   inflating: __MACOSX/test_images/._2650.jpg
#   inflating: test_images/10317.jpg
#   inflating: __MACOSX/test_images/._10317.jpg
#   inflating: test_images/5659.jpg
#   inflating: __MACOSX/test_images/._5659.jpg
#   inflating: test_images/2136.jpg
#   inflating: __MACOSX/test_images/._2136.jpg
#   inflating: test_images/10471.jpg
#   inflating: __MACOSX/test_images/._10471.jpg
#   inflating: test_images/3228.jpg
#   inflating: __MACOSX/test_images/._3228.jpg
#   inflating: test_images/7.jpg
#   inflating: __MACOSX/test_images/._7.jpg
#   inflating: test_images/5881.jpg
#   inflating: __MACOSX/test_images/._5881.jpg
#   inflating: test_images/4547.jpg
#   inflating: __MACOSX/test_images/._4547.jpg
#   inflating: test_images/6350.jpg
#   inflating: __MACOSX/test_images/._6350.jpg
#   inflating: test_images/9063.jpg
#   inflating: __MACOSX/test_images/._9063.jpg
#   inflating: test_images/8369.jpg
#   inflating: __MACOSX/test_images/._8369.jpg
#   inflating: test_images/6344.jpg
#   inflating: __MACOSX/test_images/._6344.jpg
#   inflating: test_images/9077.jpg
#   inflating: __MACOSX/test_images/._9077.jpg
#   inflating: test_images/2122.jpg
#   inflating: __MACOSX/test_images/._2122.jpg
#   inflating: test_images/10465.jpg
#   inflating: __MACOSX/test_images/._10465.jpg
#   inflating: test_images/5895.jpg
#   inflating: __MACOSX/test_images/._5895.jpg
#   inflating: test_images/4553.jpg
#   inflating: __MACOSX/test_images/._4553.jpg
#   inflating: test_images/4235.jpg
#   inflating: __MACOSX/test_images/._4235.jpg
#   inflating: test_images/2644.jpg
#   inflating: __MACOSX/test_images/._2644.jpg
#   inflating: test_images/10303.jpg
#   inflating: __MACOSX/test_images/._10303.jpg
#   inflating: test_images/41.jpg
#   inflating: __MACOSX/test_images/._41.jpg
#   inflating: test_images/6422.jpg
#   inflating: __MACOSX/test_images/._6422.jpg
#   inflating: test_images/9711.jpg
#   inflating: __MACOSX/test_images/._9711.jpg
#   inflating: test_images/801.jpg
#   inflating: __MACOSX/test_images/._801.jpg
#   inflating: test_images/11035.jpg
#   inflating: __MACOSX/test_images/._11035.jpg
#   inflating: test_images/3572.jpg
#   inflating: __MACOSX/test_images/._3572.jpg
#   inflating: test_images/5103.jpg
#   inflating: __MACOSX/test_images/._5103.jpg
#   inflating: test_images/9739.jpg
#   inflating: __MACOSX/test_images/._9739.jpg
#   inflating: test_images/69.jpg
#   inflating: __MACOSX/test_images/._69.jpg
#   inflating: test_images/1365.jpg
#   inflating: __MACOSX/test_images/._1365.jpg
#   inflating: test_images/8427.jpg
#   inflating: __MACOSX/test_images/._8427.jpg
#   inflating: test_images/829.jpg
#   inflating: __MACOSX/test_images/._829.jpg
#   inflating: test_images/7714.jpg
#   inflating: __MACOSX/test_images/._7714.jpg
#   inflating: test_images/8341.jpg
#   inflating: __MACOSX/test_images/._8341.jpg
#   inflating: test_images/7072.jpg
#   inflating: __MACOSX/test_images/._7072.jpg
#   inflating: test_images/1403.jpg
#   inflating: __MACOSX/test_images/._1403.jpg
#   inflating: test_images/197.jpg
#   inflating: __MACOSX/test_images/._197.jpg
#   inflating: test_images/5665.jpg
#   inflating: __MACOSX/test_images/._5665.jpg
#   inflating: test_images/3214.jpg
#   inflating: __MACOSX/test_images/._3214.jpg
#   inflating: test_images/5671.jpg
#   inflating: __MACOSX/test_images/._5671.jpg
#   inflating: test_images/10459.jpg
#   inflating: __MACOSX/test_images/._10459.jpg
#   inflating: test_images/3200.jpg
#   inflating: __MACOSX/test_images/._3200.jpg
#   inflating: test_images/8355.jpg
#   inflating: __MACOSX/test_images/._8355.jpg
#   inflating: test_images/7066.jpg
#   inflating: __MACOSX/test_images/._7066.jpg
#   inflating: test_images/183.jpg
#   inflating: __MACOSX/test_images/._183.jpg
#   inflating: test_images/1417.jpg
#   inflating: __MACOSX/test_images/._1417.jpg
#   inflating: test_images/6378.jpg
#   inflating: __MACOSX/test_images/._6378.jpg
#   inflating: test_images/1371.jpg
#   inflating: __MACOSX/test_images/._1371.jpg
#   inflating: test_images/8433.jpg
#   inflating: __MACOSX/test_images/._8433.jpg
#   inflating: test_images/7700.jpg
#   inflating: __MACOSX/test_images/._7700.jpg
#   inflating: test_images/4209.jpg
#   inflating: __MACOSX/test_images/._4209.jpg
#   inflating: test_images/11021.jpg
#   inflating: __MACOSX/test_images/._11021.jpg
#   inflating: test_images/3566.jpg
#   inflating: __MACOSX/test_images/._3566.jpg
#   inflating: test_images/2678.jpg
#   inflating: __MACOSX/test_images/._2678.jpg
#   inflating: test_images/5117.jpg
#   inflating: __MACOSX/test_images/._5117.jpg
#   inflating: test_images/2693.jpg
#   inflating: __MACOSX/test_images/._2693.jpg
#   inflating: test_images/96.jpg
#   inflating: __MACOSX/test_images/._96.jpg
#   inflating: test_images/7933.jpg
#   inflating: __MACOSX/test_images/._7933.jpg
#   inflating: test_images/168.jpg
#   inflating: __MACOSX/test_images/._168.jpg
#   inflating: test_images/6393.jpg
#   inflating: __MACOSX/test_images/._6393.jpg
#   inflating: test_images/5842.jpg
#   inflating: __MACOSX/test_images/._5842.jpg
#   inflating: test_images/4584.jpg
#   inflating: __MACOSX/test_images/._4584.jpg
#   inflating: test_images/5856.jpg
#   inflating: __MACOSX/test_images/._5856.jpg
#   inflating: test_images/4590.jpg
#   inflating: __MACOSX/test_images/._4590.jpg
#   inflating: test_images/6387.jpg
#   inflating: __MACOSX/test_images/._6387.jpg
#   inflating: test_images/7099.jpg
#   inflating: __MACOSX/test_images/._7099.jpg
#   inflating: test_images/82.jpg
#   inflating: __MACOSX/test_images/._82.jpg
#   inflating: test_images/7927.jpg
#   inflating: __MACOSX/test_images/._7927.jpg
#   inflating: test_images/2687.jpg
#   inflating: __MACOSX/test_images/._2687.jpg
#   inflating: test_images/3599.jpg
#   inflating: __MACOSX/test_images/._3599.jpg
#   inflating: test_images/9922.jpg
#   inflating: __MACOSX/test_images/._9922.jpg
#   inflating: test_images/632.jpg
#   inflating: __MACOSX/test_images/._632.jpg
#   inflating: test_images/2877.jpg
#   inflating: __MACOSX/test_images/._2877.jpg
#   inflating: test_images/154.jpg
#   inflating: __MACOSX/test_images/._154.jpg
#   inflating: test_images/8382.jpg
#   inflating: __MACOSX/test_images/._8382.jpg
#   inflating: test_images/140.jpg
#   inflating: __MACOSX/test_images/._140.jpg
#   inflating: test_images/9088.jpg
#   inflating: __MACOSX/test_images/._9088.jpg
#   inflating: test_images/8396.jpg
#   inflating: __MACOSX/test_images/._8396.jpg
#   inflating: test_images/2863.jpg
#   inflating: __MACOSX/test_images/._2863.jpg
#   inflating: test_images/9936.jpg
#   inflating: __MACOSX/test_images/._9936.jpg
#   inflating: test_images/626.jpg
#   inflating: __MACOSX/test_images/._626.jpg
#   inflating: test_images/9261.jpg
#   inflating: __MACOSX/test_images/._9261.jpg
#   inflating: test_images/6152.jpg
#   inflating: __MACOSX/test_images/._6152.jpg
#   inflating: test_images/4745.jpg
#   inflating: __MACOSX/test_images/._4745.jpg
#   inflating: test_images/10673.jpg
#   inflating: __MACOSX/test_images/._10673.jpg
#   inflating: test_images/2334.jpg
#   inflating: __MACOSX/test_images/._2334.jpg
#   inflating: test_images/3994.jpg
#   inflating: __MACOSX/test_images/._3994.jpg
#   inflating: test_images/10115.jpg
#   inflating: __MACOSX/test_images/._10115.jpg
#   inflating: test_images/2452.jpg
#   inflating: __MACOSX/test_images/._2452.jpg
#   inflating: test_images/4023.jpg
#   inflating: __MACOSX/test_images/._4023.jpg
#   inflating: test_images/8619.jpg
#   inflating: __MACOSX/test_images/._8619.jpg
#   inflating: test_images/9507.jpg
#   inflating: __MACOSX/test_images/._9507.jpg
#   inflating: test_images/6634.jpg
#   inflating: __MACOSX/test_images/._6634.jpg
#   inflating: test_images/9513.jpg
#   inflating: __MACOSX/test_images/._9513.jpg
#   inflating: test_images/6620.jpg
#   inflating: __MACOSX/test_images/._6620.jpg
#   inflating: test_images/5329.jpg
#   inflating: __MACOSX/test_images/._5329.jpg
#   inflating: test_images/3980.jpg
#   inflating: __MACOSX/test_images/._3980.jpg
#   inflating: test_images/10101.jpg
#   inflating: __MACOSX/test_images/._10101.jpg
#   inflating: test_images/2446.jpg
#   inflating: __MACOSX/test_images/._2446.jpg
#   inflating: test_images/3758.jpg
#   inflating: __MACOSX/test_images/._3758.jpg
#   inflating: test_images/4037.jpg
#   inflating: __MACOSX/test_images/._4037.jpg
#   inflating: test_images/4751.jpg
#   inflating: __MACOSX/test_images/._4751.jpg
#   inflating: test_images/4989.jpg
#   inflating: __MACOSX/test_images/._4989.jpg
#   inflating: test_images/10667.jpg
#   inflating: __MACOSX/test_images/._10667.jpg
#   inflating: test_images/2320.jpg
#   inflating: __MACOSX/test_images/._2320.jpg
#   inflating: test_images/9275.jpg
#   inflating: __MACOSX/test_images/._9275.jpg
#   inflating: test_images/6146.jpg
#   inflating: __MACOSX/test_images/._6146.jpg
#   inflating: test_images/1629.jpg
#   inflating: __MACOSX/test_images/._1629.jpg
#   inflating: test_images/7258.jpg
#   inflating: __MACOSX/test_images/._7258.jpg
#   inflating: test_images/10897.jpg
#   inflating: __MACOSX/test_images/._10897.jpg
#   inflating: test_images/4779.jpg
#   inflating: __MACOSX/test_images/._4779.jpg
#   inflating: test_images/3016.jpg
#   inflating: __MACOSX/test_images/._3016.jpg
#   inflating: test_images/2308.jpg
#   inflating: __MACOSX/test_images/._2308.jpg
#   inflating: test_images/5467.jpg
#   inflating: __MACOSX/test_images/._5467.jpg
#   inflating: test_images/395.jpg
#   inflating: __MACOSX/test_images/._395.jpg
#   inflating: test_images/1601.jpg
#   inflating: __MACOSX/test_images/._1601.jpg
#   inflating: test_images/7270.jpg
#   inflating: __MACOSX/test_images/._7270.jpg
#   inflating: test_images/8143.jpg
#   inflating: __MACOSX/test_images/._8143.jpg
#   inflating: test_images/7516.jpg
#   inflating: __MACOSX/test_images/._7516.jpg
#   inflating: test_images/8625.jpg
#   inflating: __MACOSX/test_images/._8625.jpg
#   inflating: test_images/1167.jpg
#   inflating: __MACOSX/test_images/._1167.jpg
#   inflating: test_images/6608.jpg
#   inflating: __MACOSX/test_images/._6608.jpg
#   inflating: test_images/5301.jpg
#   inflating: __MACOSX/test_images/._5301.jpg
#   inflating: test_images/10129.jpg
#   inflating: __MACOSX/test_images/._10129.jpg
#   inflating: test_images/3770.jpg
#   inflating: __MACOSX/test_images/._3770.jpg
#   inflating: test_images/5315.jpg
#   inflating: __MACOSX/test_images/._5315.jpg
#   inflating: test_images/3764.jpg
#   inflating: __MACOSX/test_images/._3764.jpg
#   inflating: test_images/7502.jpg
#   inflating: __MACOSX/test_images/._7502.jpg
#   inflating: test_images/8631.jpg
#   inflating: __MACOSX/test_images/._8631.jpg
#   inflating: test_images/1173.jpg
#   inflating: __MACOSX/test_images/._1173.jpg
#   inflating: test_images/9249.jpg
#   inflating: __MACOSX/test_images/._9249.jpg
#   inflating: test_images/1615.jpg
#   inflating: __MACOSX/test_images/._1615.jpg
#   inflating: test_images/381.jpg
#   inflating: __MACOSX/test_images/._381.jpg
#   inflating: test_images/7264.jpg
#   inflating: __MACOSX/test_images/._7264.jpg
#   inflating: test_images/8157.jpg
#   inflating: __MACOSX/test_images/._8157.jpg
#   inflating: test_images/10883.jpg
#   inflating: __MACOSX/test_images/._10883.jpg
#   inflating: test_images/3002.jpg
#   inflating: __MACOSX/test_images/._3002.jpg
#   inflating: test_images/5473.jpg
#   inflating: __MACOSX/test_images/._5473.jpg
#   inflating: test_images/5498.jpg
#   inflating: __MACOSX/test_images/._5498.jpg
#   inflating: test_images/4786.jpg
#   inflating: __MACOSX/test_images/._4786.jpg
#   inflating: test_images/10868.jpg
#   inflating: __MACOSX/test_images/._10868.jpg
#   inflating: test_images/1826.jpg
#   inflating: __MACOSX/test_images/._1826.jpg
# ...
#   inflating: test_images/3617.jpg
#   inflating: __MACOSX/test_images/._3617.jpg
#   inflating: test_images/3171.jpg
#   inflating: __MACOSX/test_images/._3171.jpg
#   inflating: test_images/5500.jpg
#   inflating: __MACOSX/test_images/._5500.jpg
#   inflating: test_images/10728.jpg
#   inflating: __MACOSX/test_images/._10728.jpg
#   inflating: test_images/1766.jpg
#   inflating: __MACOSX/test_images/._1766.jpg
#   inflating: test_images/6009.jpg
#   inflating: __MACOSX/test_images/._6009.jpg
#   inflating: test_images/7317.jpg
#   inflating: __MACOSX/test_images/._7317.jpg
#   inflating: test_images/8024.jpg
#   inflating: __MACOSX/test_images/._8024.jpg
#   inflating: test_images/6196.jpg
#   inflating: __MACOSX/test_images/._6196.jpg
#   inflating: test_images/1821.jpg
#   inflating: __MACOSX/test_images/._1821.jpg
#   inflating: test_images/7288.jpg
#   inflating: __MACOSX/test_images/._7288.jpg
#   inflating: test_images/4781.jpg
#   inflating: __MACOSX/test_images/._4781.jpg
#   inflating: test_images/4959.jpg
#   inflating: __MACOSX/test_images/._4959.jpg
#   inflating: test_images/3950.jpg
#   inflating: __MACOSX/test_images/._3950.jpg
#   inflating: test_images/2496.jpg
#   inflating: __MACOSX/test_images/._2496.jpg
#   inflating: test_images/3788.jpg
#   inflating: __MACOSX/test_images/._3788.jpg
#   inflating: test_images/6828.jpg
#   inflating: __MACOSX/test_images/._6828.jpg
#   inflating: test_images/8805.jpg
#   inflating: __MACOSX/test_images/._8805.jpg
#   inflating: test_images/8811.jpg
#   inflating: __MACOSX/test_images/._8811.jpg
#   inflating: test_images/3944.jpg
#   inflating: __MACOSX/test_images/._3944.jpg
#   inflating: test_images/2482.jpg
#   inflating: __MACOSX/test_images/._2482.jpg
#   inflating: test_images/4795.jpg
#   inflating: __MACOSX/test_images/._4795.jpg
#   inflating: test_images/6182.jpg
#   inflating: __MACOSX/test_images/._6182.jpg
#   inflating: test_images/379.jpg
#   inflating: __MACOSX/test_images/._379.jpg
#   inflating: test_images/1835.jpg
#   inflating: __MACOSX/test_images/._1835.jpg
#   inflating: test_images/10853.jpg
#   inflating: __MACOSX/test_images/._10853.jpg
#   inflating: test_images/4965.jpg
#   inflating: __MACOSX/test_images/._4965.jpg
#   inflating: test_images/9299.jpg
#   inflating: __MACOSX/test_images/._9299.jpg
#   inflating: test_images/351.jpg
#   inflating: __MACOSX/test_images/._351.jpg
#   inflating: test_images/8187.jpg
#   inflating: __MACOSX/test_images/._8187.jpg
#   inflating: test_images/6814.jpg
#   inflating: __MACOSX/test_images/._6814.jpg
#   inflating: test_images/8839.jpg
#   inflating: __MACOSX/test_images/._8839.jpg
#   inflating: test_images/437.jpg
#   inflating: __MACOSX/test_images/._437.jpg
#   inflating: test_images/3978.jpg
#   inflating: __MACOSX/test_images/._3978.jpg
#   inflating: test_images/6800.jpg
#   inflating: __MACOSX/test_images/._6800.jpg
#   inflating: test_images/423.jpg
#   inflating: __MACOSX/test_images/._423.jpg
#   inflating: test_images/345.jpg
#   inflating: __MACOSX/test_images/._345.jpg
#   inflating: test_images/1809.jpg
#   inflating: __MACOSX/test_images/._1809.jpg
#   inflating: test_images/8193.jpg
#   inflating: __MACOSX/test_images/._8193.jpg
#   inflating: test_images/10847.jpg
#   inflating: __MACOSX/test_images/._10847.jpg
#   inflating: test_images/4971.jpg
#   inflating: __MACOSX/test_images/._4971.jpg
#   inflating: test_images/10674.jpg
#   inflating: __MACOSX/test_images/._10674.jpg
#   inflating: test_images/2333.jpg
#   inflating: __MACOSX/test_images/._2333.jpg
#   inflating: test_images/4742.jpg
#   inflating: __MACOSX/test_images/._4742.jpg
#   inflating: test_images/8178.jpg
#   inflating: __MACOSX/test_images/._8178.jpg
#   inflating: test_images/9266.jpg
#   inflating: __MACOSX/test_images/._9266.jpg
#   inflating: test_images/6155.jpg
#   inflating: __MACOSX/test_images/._6155.jpg
#   inflating: test_images/9500.jpg
#   inflating: __MACOSX/test_images/._9500.jpg
#   inflating: test_images/6633.jpg
#   inflating: __MACOSX/test_images/._6633.jpg
#   inflating: test_images/4024.jpg
#   inflating: __MACOSX/test_images/._4024.jpg
#   inflating: test_images/3993.jpg
#   inflating: __MACOSX/test_images/._3993.jpg
#   inflating: test_images/10112.jpg
#   inflating: __MACOSX/test_images/._10112.jpg
#   inflating: test_images/2455.jpg
#   inflating: __MACOSX/test_images/._2455.jpg
#   inflating: test_images/4030.jpg
#   inflating: __MACOSX/test_images/._4030.jpg
#   inflating: test_images/3987.jpg
#   inflating: __MACOSX/test_images/._3987.jpg
#   inflating: test_images/10106.jpg
#   inflating: __MACOSX/test_images/._10106.jpg
#   inflating: test_images/2441.jpg
#   inflating: __MACOSX/test_images/._2441.jpg
#   inflating: test_images/1148.jpg
#   inflating: __MACOSX/test_images/._1148.jpg
#   inflating: test_images/9514.jpg
#   inflating: __MACOSX/test_images/._9514.jpg
#   inflating: test_images/6627.jpg
#   inflating: __MACOSX/test_images/._6627.jpg
#   inflating: test_images/7539.jpg
#   inflating: __MACOSX/test_images/._7539.jpg
#   inflating: test_images/9272.jpg
#   inflating: __MACOSX/test_images/._9272.jpg
#   inflating: test_images/6141.jpg
#   inflating: __MACOSX/test_images/._6141.jpg
#   inflating: test_images/10660.jpg
#   inflating: __MACOSX/test_images/._10660.jpg
#   inflating: test_images/2327.jpg
#   inflating: __MACOSX/test_images/._2327.jpg
#   inflating: test_images/5448.jpg
#   inflating: __MACOSX/test_images/._5448.jpg
#   inflating: test_images/4756.jpg
#   inflating: __MACOSX/test_images/._4756.jpg
#   inflating: test_images/3039.jpg
#   inflating: __MACOSX/test_images/._3039.jpg
#   inflating: test_images/7277.jpg
#   inflating: __MACOSX/test_images/._7277.jpg
#   inflating: test_images/8144.jpg
#   inflating: __MACOSX/test_images/._8144.jpg
#   inflating: test_images/6169.jpg
#   inflating: __MACOSX/test_images/._6169.jpg
#   inflating: test_images/1606.jpg
#   inflating: __MACOSX/test_images/._1606.jpg
#   inflating: test_images/392.jpg
#   inflating: __MACOSX/test_images/._392.jpg
#   inflating: test_images/10648.jpg
#   inflating: __MACOSX/test_images/._10648.jpg
#   inflating: test_images/5460.jpg
#   inflating: __MACOSX/test_images/._5460.jpg
#   inflating: test_images/10890.jpg
#   inflating: __MACOSX/test_images/._10890.jpg
#   inflating: test_images/3011.jpg
#   inflating: __MACOSX/test_images/._3011.jpg
#   inflating: test_images/3777.jpg
#   inflating: __MACOSX/test_images/._3777.jpg
#   inflating: test_images/4018.jpg
#   inflating: __MACOSX/test_images/._4018.jpg
#   inflating: test_images/5306.jpg
#   inflating: __MACOSX/test_images/._5306.jpg
#   inflating: test_images/2469.jpg
#   inflating: __MACOSX/test_images/._2469.jpg
#   inflating: test_images/1160.jpg
#   inflating: __MACOSX/test_images/._1160.jpg
#   inflating: test_images/7511.jpg
#   inflating: __MACOSX/test_images/._7511.jpg
#   inflating: test_images/8622.jpg
#   inflating: __MACOSX/test_images/._8622.jpg
#   inflating: test_images/1174.jpg
#   inflating: __MACOSX/test_images/._1174.jpg
#   inflating: test_images/9528.jpg
#   inflating: __MACOSX/test_images/._9528.jpg
#   inflating: test_images/7505.jpg
#   inflating: __MACOSX/test_images/._7505.jpg
#   inflating: test_images/8636.jpg
#   inflating: __MACOSX/test_images/._8636.jpg
#   inflating: test_images/3763.jpg
#   inflating: __MACOSX/test_images/._3763.jpg
#   inflating: test_images/5312.jpg
#   inflating: __MACOSX/test_images/._5312.jpg
#   inflating: test_images/5474.jpg
#   inflating: __MACOSX/test_images/._5474.jpg
#   inflating: test_images/10884.jpg
#   inflating: __MACOSX/test_images/._10884.jpg
#   inflating: test_images/3005.jpg
#   inflating: __MACOSX/test_images/._3005.jpg
#   inflating: test_images/7263.jpg
#   inflating: __MACOSX/test_images/._7263.jpg
#   inflating: test_images/8150.jpg
#   inflating: __MACOSX/test_images/._8150.jpg
#   inflating: test_images/386.jpg
#   inflating: __MACOSX/test_images/._386.jpg
#   inflating: test_images/1612.jpg
#   inflating: __MACOSX/test_images/._1612.jpg
#   inflating: test_images/91.jpg
#   inflating: __MACOSX/test_images/._91.jpg
#   inflating: test_images/7934.jpg
#   inflating: __MACOSX/test_images/._7934.jpg
#   inflating: test_images/609.jpg
#   inflating: __MACOSX/test_images/._609.jpg
#   inflating: test_images/9919.jpg
#   inflating: __MACOSX/test_images/._9919.jpg
#   inflating: test_images/2694.jpg
#   inflating: __MACOSX/test_images/._2694.jpg
#   inflating: test_images/5845.jpg
#   inflating: __MACOSX/test_images/._5845.jpg
#   inflating: test_images/4583.jpg
#   inflating: __MACOSX/test_images/._4583.jpg
#   inflating: test_images/6394.jpg
#   inflating: __MACOSX/test_images/._6394.jpg
#   inflating: test_images/6380.jpg
#   inflating: __MACOSX/test_images/._6380.jpg
#   inflating: test_images/5689.jpg
#   inflating: __MACOSX/test_images/._5689.jpg
#   inflating: test_images/5851.jpg
#   inflating: __MACOSX/test_images/._5851.jpg
#   inflating: test_images/4597.jpg
#   inflating: __MACOSX/test_images/._4597.jpg
#   inflating: test_images/2858.jpg
#   inflating: __MACOSX/test_images/._2858.jpg
#   inflating: test_images/2680.jpg
#   inflating: __MACOSX/test_images/._2680.jpg
#   inflating: test_images/85.jpg
#   inflating: __MACOSX/test_images/._85.jpg
#   inflating: test_images/7920.jpg
#   inflating: __MACOSX/test_images/._7920.jpg
#   inflating: test_images/1389.jpg
#   inflating: __MACOSX/test_images/._1389.jpg
#   inflating: test_images/2870.jpg
#   inflating: __MACOSX/test_images/._2870.jpg
#   inflating: test_images/635.jpg
#   inflating: __MACOSX/test_images/._635.jpg
#   inflating: test_images/7908.jpg
#   inflating: __MACOSX/test_images/._7908.jpg
#   inflating: test_images/9925.jpg
#   inflating: __MACOSX/test_images/._9925.jpg
#   inflating: test_images/8385.jpg
#   inflating: __MACOSX/test_images/._8385.jpg
#   inflating: test_images/153.jpg
#   inflating: __MACOSX/test_images/._153.jpg
#   inflating: test_images/10489.jpg
#   inflating: __MACOSX/test_images/._10489.jpg
#   inflating: test_images/5879.jpg
#   inflating: __MACOSX/test_images/._5879.jpg
#   inflating: test_images/8391.jpg
#   inflating: __MACOSX/test_images/._8391.jpg
#   inflating: test_images/147.jpg
#   inflating: __MACOSX/test_images/._147.jpg
#   inflating: test_images/621.jpg
#   inflating: __MACOSX/test_images/._621.jpg
#   inflating: test_images/9931.jpg
#   inflating: __MACOSX/test_images/._9931.jpg
#   inflating: test_images/2864.jpg
#   inflating: __MACOSX/test_images/._2864.jpg
#   inflating: test_images/2657.jpg
#   inflating: __MACOSX/test_images/._2657.jpg
#   inflating: test_images/10310.jpg
#   inflating: __MACOSX/test_images/._10310.jpg
#   inflating: test_images/5138.jpg
#   inflating: __MACOSX/test_images/._5138.jpg
#   inflating: test_images/4226.jpg
#   inflating: __MACOSX/test_images/._4226.jpg
#   inflating: test_images/3549.jpg
#   inflating: __MACOSX/test_images/._3549.jpg
#   inflating: test_images/812.jpg
#   inflating: __MACOSX/test_images/._812.jpg
#   inflating: test_images/6431.jpg
#   inflating: __MACOSX/test_images/._6431.jpg
#   inflating: test_images/52.jpg
#   inflating: __MACOSX/test_images/._52.jpg
#   inflating: test_images/9702.jpg
#   inflating: __MACOSX/test_images/._9702.jpg
#   inflating: test_images/1438.jpg
#   inflating: __MACOSX/test_images/._1438.jpg
#   inflating: test_images/6357.jpg
#   inflating: __MACOSX/test_images/._6357.jpg
#   inflating: test_images/9064.jpg
#   inflating: __MACOSX/test_images/._9064.jpg
#   inflating: test_images/7049.jpg
#   inflating: __MACOSX/test_images/._7049.jpg
#   inflating: test_images/5886.jpg
#   inflating: __MACOSX/test_images/._5886.jpg
#   inflating: test_images/0.jpg
#   inflating: __MACOSX/test_images/._0.jpg
#   inflating: test_images/4540.jpg
#   inflating: __MACOSX/test_images/._4540.jpg
#   inflating: test_images/2131.jpg
#   inflating: __MACOSX/test_images/._2131.jpg
#   inflating: test_images/10476.jpg
#   inflating: __MACOSX/test_images/._10476.jpg
#   inflating: test_images/5892.jpg
#   inflating: __MACOSX/test_images/._5892.jpg
#   inflating: test_images/4554.jpg
#   inflating: __MACOSX/test_images/._4554.jpg
#   inflating: test_images/2125.jpg
#   inflating: __MACOSX/test_images/._2125.jpg
#   inflating: test_images/10462.jpg
#   inflating: __MACOSX/test_images/._10462.jpg
#   inflating: test_images/6343.jpg
#   inflating: __MACOSX/test_images/._6343.jpg
#   inflating: test_images/9070.jpg
#   inflating: __MACOSX/test_images/._9070.jpg
#   inflating: test_images/806.jpg
#   inflating: __MACOSX/test_images/._806.jpg
#   inflating: test_images/8408.jpg
#   inflating: __MACOSX/test_images/._8408.jpg
#   inflating: test_images/46.jpg
#   inflating: __MACOSX/test_images/._46.jpg
#   inflating: test_images/6425.jpg
#   inflating: __MACOSX/test_images/._6425.jpg
#   inflating: test_images/9716.jpg
#   inflating: __MACOSX/test_images/._9716.jpg
#   inflating: test_images/2643.jpg
#   inflating: __MACOSX/test_images/._2643.jpg
#   inflating: test_images/10304.jpg
#   inflating: __MACOSX/test_images/._10304.jpg
#   inflating: test_images/4232.jpg
#   inflating: __MACOSX/test_images/._4232.jpg
#   inflating: test_images/8420.jpg
#   inflating: __MACOSX/test_images/._8420.jpg
#   inflating: test_images/7713.jpg
#   inflating: __MACOSX/test_images/._7713.jpg
#   inflating: test_images/1362.jpg
#   inflating: __MACOSX/test_images/._1362.jpg
#   inflating: test_images/5104.jpg
#   inflating: __MACOSX/test_images/._5104.jpg
#   inflating: test_images/11032.jpg
#   inflating: __MACOSX/test_images/._11032.jpg
#   inflating: test_images/3575.jpg
#   inflating: __MACOSX/test_images/._3575.jpg
#   inflating: test_images/3213.jpg
#   inflating: __MACOSX/test_images/._3213.jpg
#   inflating: test_images/5662.jpg
#   inflating: __MACOSX/test_images/._5662.jpg
#   inflating: test_images/190.jpg
#   inflating: __MACOSX/test_images/._190.jpg
#   inflating: test_images/1404.jpg
#   inflating: __MACOSX/test_images/._1404.jpg
#   inflating: test_images/9058.jpg
#   inflating: __MACOSX/test_images/._9058.jpg
#   inflating: test_images/8346.jpg
#   inflating: __MACOSX/test_images/._8346.jpg
#   inflating: test_images/7075.jpg
#   inflating: __MACOSX/test_images/._7075.jpg
#   inflating: test_images/1410.jpg
#   inflating: __MACOSX/test_images/._1410.jpg
#   inflating: test_images/184.jpg
#   inflating: __MACOSX/test_images/._184.jpg
#   inflating: test_images/8352.jpg
#   inflating: __MACOSX/test_images/._8352.jpg
#   inflating: test_images/7061.jpg
#   inflating: __MACOSX/test_images/._7061.jpg
#   inflating: test_images/3207.jpg
#   inflating: __MACOSX/test_images/._3207.jpg
#   inflating: test_images/4568.jpg
#   inflating: __MACOSX/test_images/._4568.jpg
#   inflating: test_images/5676.jpg
#   inflating: __MACOSX/test_images/._5676.jpg
#   inflating: test_images/2119.jpg
#   inflating: __MACOSX/test_images/._2119.jpg
#   inflating: test_images/10338.jpg
#   inflating: __MACOSX/test_images/._10338.jpg
#   inflating: test_images/5110.jpg
#   inflating: __MACOSX/test_images/._5110.jpg
#   inflating: test_images/11026.jpg
#   inflating: __MACOSX/test_images/._11026.jpg
#   inflating: test_images/3561.jpg
#   inflating: __MACOSX/test_images/._3561.jpg
#   inflating: test_images/8434.jpg
#   inflating: __MACOSX/test_images/._8434.jpg
#   inflating: test_images/7707.jpg
#   inflating: __MACOSX/test_images/._7707.jpg
#   inflating: test_images/6419.jpg
#   inflating: __MACOSX/test_images/._6419.jpg
#   inflating: test_images/1376.jpg
#   inflating: __MACOSX/test_images/._1376.jpg

# %%
import os
import random
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import torchvision
import torchvision.models as models

from torch.utils.data import Dataset, DataLoader, BatchSampler, random_split
from torchvision import transforms
from PIL import Image

import timm

# %%
for m in timm.list_models(pretrained=True):
  print(m)
# Out:
# aimv2_1b_patch14_224.apple_pt
# aimv2_1b_patch14_336.apple_pt
# aimv2_1b_patch14_448.apple_pt
# aimv2_3b_patch14_224.apple_pt
# aimv2_3b_patch14_336.apple_pt
# aimv2_3b_patch14_448.apple_pt
# aimv2_huge_patch14_224.apple_pt
# aimv2_huge_patch14_336.apple_pt
# aimv2_huge_patch14_448.apple_pt
# aimv2_large_patch14_224.apple_pt
# aimv2_large_patch14_224.apple_pt_dist
# aimv2_large_patch14_336.apple_pt
# aimv2_large_patch14_336.apple_pt_dist
# aimv2_large_patch14_448.apple_pt
# bat_resnext26ts.ch_in1k
# beit_base_patch16_224.in22k_ft_in22k
# beit_base_patch16_224.in22k_ft_in22k_in1k
# beit_base_patch16_384.in22k_ft_in22k_in1k
# beit_large_patch16_224.in22k_ft_in22k
# beit_large_patch16_224.in22k_ft_in22k_in1k
# beit_large_patch16_384.in22k_ft_in22k_in1k
# beit_large_patch16_512.in22k_ft_in22k_in1k
# beitv2_base_patch16_224.in1k_ft_in1k
# beitv2_base_patch16_224.in1k_ft_in22k
# beitv2_base_patch16_224.in1k_ft_in22k_in1k
# beitv2_large_patch16_224.in1k_ft_in1k
# beitv2_large_patch16_224.in1k_ft_in22k
# beitv2_large_patch16_224.in1k_ft_in22k_in1k
# botnet26t_256.c1_in1k
# caformer_b36.sail_in1k
# caformer_b36.sail_in1k_384
# caformer_b36.sail_in22k
# caformer_b36.sail_in22k_ft_in1k
# caformer_b36.sail_in22k_ft_in1k_384
# caformer_m36.sail_in1k
# caformer_m36.sail_in1k_384
# caformer_m36.sail_in22k
# caformer_m36.sail_in22k_ft_in1k
# caformer_m36.sail_in22k_ft_in1k_384
# caformer_s18.sail_in1k
# caformer_s18.sail_in1k_384
# caformer_s18.sail_in22k
# caformer_s18.sail_in22k_ft_in1k
# caformer_s18.sail_in22k_ft_in1k_384
# caformer_s36.sail_in1k
# caformer_s36.sail_in1k_384
# caformer_s36.sail_in22k
# caformer_s36.sail_in22k_ft_in1k
# caformer_s36.sail_in22k_ft_in1k_384
# cait_m36_384.fb_dist_in1k
# cait_m48_448.fb_dist_in1k
# cait_s24_224.fb_dist_in1k
# cait_s24_384.fb_dist_in1k
# cait_s36_384.fb_dist_in1k
# cait_xs24_384.fb_dist_in1k
# cait_xxs24_224.fb_dist_in1k
# cait_xxs24_384.fb_dist_in1k
# cait_xxs36_224.fb_dist_in1k
# cait_xxs36_384.fb_dist_in1k
# coat_lite_medium.in1k
# coat_lite_medium_384.in1k
# coat_lite_mini.in1k
# coat_lite_small.in1k
# coat_lite_tiny.in1k
# coat_mini.in1k
# coat_small.in1k
# coat_tiny.in1k
# coatnet_0_rw_224.sw_in1k
# coatnet_1_rw_224.sw_in1k
# coatnet_2_rw_224.sw_in12k
# coatnet_2_rw_224.sw_in12k_ft_in1k
# coatnet_3_rw_224.sw_in12k
# coatnet_bn_0_rw_224.sw_in1k
# coatnet_nano_rw_224.sw_in1k
# coatnet_rmlp_1_rw2_224.sw_in12k
# coatnet_rmlp_1_rw2_224.sw_in12k_ft_in1k
# coatnet_rmlp_1_rw_224.sw_in1k
# coatnet_rmlp_2_rw_224.sw_in1k
# coatnet_rmlp_2_rw_224.sw_in12k
# coatnet_rmlp_2_rw_224.sw_in12k_ft_in1k
# coatnet_rmlp_2_rw_384.sw_in12k_ft_in1k
# coatnet_rmlp_nano_rw_224.sw_in1k
# coatnext_nano_rw_224.sw_in1k
# convformer_b36.sail_in1k
# convformer_b36.sail_in1k_384
# convformer_b36.sail_in22k
# convformer_b36.sail_in22k_ft_in1k
# convformer_b36.sail_in22k_ft_in1k_384
# convformer_m36.sail_in1k
# convformer_m36.sail_in1k_384
# convformer_m36.sail_in22k
# convformer_m36.sail_in22k_ft_in1k
# convformer_m36.sail_in22k_ft_in1k_384
# convformer_s18.sail_in1k
# convformer_s18.sail_in1k_384
# convformer_s18.sail_in22k
# convformer_s18.sail_in22k_ft_in1k
# convformer_s18.sail_in22k_ft_in1k_384
# convformer_s36.sail_in1k
# convformer_s36.sail_in1k_384
# convformer_s36.sail_in22k
# convformer_s36.sail_in22k_ft_in1k
# convformer_s36.sail_in22k_ft_in1k_384
# convit_base.fb_in1k
# convit_small.fb_in1k
# convit_tiny.fb_in1k
# convmixer_768_32.in1k
# convmixer_1024_20_ks9_p14.in1k
# convmixer_1536_20.in1k
# convnext_atto.d2_in1k
# convnext_atto_ols.a2_in1k
# convnext_base.clip_laion2b
# convnext_base.clip_laion2b_augreg
# convnext_base.clip_laion2b_augreg_ft_in1k
# convnext_base.clip_laion2b_augreg_ft_in12k
# convnext_base.clip_laion2b_augreg_ft_in12k_in1k
# convnext_base.clip_laion2b_augreg_ft_in12k_in1k_384
# convnext_base.clip_laiona
# convnext_base.clip_laiona_320
# convnext_base.clip_laiona_augreg_320
# convnext_base.clip_laiona_augreg_ft_in1k_384
# convnext_base.fb_in1k
# convnext_base.fb_in22k
# convnext_base.fb_in22k_ft_in1k
# convnext_base.fb_in22k_ft_in1k_384
# convnext_femto.d1_in1k
# convnext_femto_ols.d1_in1k
# convnext_large.fb_in1k
# convnext_large.fb_in22k
# convnext_large.fb_in22k_ft_in1k
# convnext_large.fb_in22k_ft_in1k_384
# convnext_large_mlp.clip_laion2b_augreg
# convnext_large_mlp.clip_laion2b_augreg_ft_in1k
# convnext_large_mlp.clip_laion2b_augreg_ft_in1k_384
# convnext_large_mlp.clip_laion2b_augreg_ft_in12k_384
# convnext_large_mlp.clip_laion2b_ft_320
# convnext_large_mlp.clip_laion2b_ft_soup_320
# convnext_large_mlp.clip_laion2b_soup_ft_in12k_320
# convnext_large_mlp.clip_laion2b_soup_ft_in12k_384
# convnext_large_mlp.clip_laion2b_soup_ft_in12k_in1k_320
# convnext_large_mlp.clip_laion2b_soup_ft_in12k_in1k_384
# convnext_nano.d1h_in1k
# convnext_nano.in12k
# convnext_nano.in12k_ft_in1k
# convnext_nano.r384_ad_in12k
# convnext_nano.r384_in12k
# convnext_nano.r384_in12k_ft_in1k
# convnext_nano_ols.d1h_in1k
# convnext_pico.d1_in1k
# convnext_pico_ols.d1_in1k
# convnext_small.fb_in1k
# convnext_small.fb_in22k
# convnext_small.fb_in22k_ft_in1k
# convnext_small.fb_in22k_ft_in1k_384
# convnext_small.in12k
# convnext_small.in12k_ft_in1k
# convnext_small.in12k_ft_in1k_384
# convnext_tiny.fb_in1k
# convnext_tiny.fb_in22k
# convnext_tiny.fb_in22k_ft_in1k
# convnext_tiny.fb_in22k_ft_in1k_384
# convnext_tiny.in12k
# convnext_tiny.in12k_ft_in1k
# convnext_tiny.in12k_ft_in1k_384
# convnext_tiny_hnf.a2h_in1k
# convnext_xlarge.fb_in22k
# convnext_xlarge.fb_in22k_ft_in1k
# convnext_xlarge.fb_in22k_ft_in1k_384
# convnext_xxlarge.clip_laion2b_rewind
# convnext_xxlarge.clip_laion2b_soup
# convnext_xxlarge.clip_laion2b_soup_ft_in1k
# convnext_xxlarge.clip_laion2b_soup_ft_in12k
# convnext_zepto_rms.ra4_e3600_r224_in1k
# convnext_zepto_rms_ols.ra4_e3600_r224_in1k
# convnextv2_atto.fcmae
# convnextv2_atto.fcmae_ft_in1k
# convnextv2_base.fcmae
# convnextv2_base.fcmae_ft_in1k
# convnextv2_base.fcmae_ft_in22k_in1k
# convnextv2_base.fcmae_ft_in22k_in1k_384
# convnextv2_femto.fcmae
# convnextv2_femto.fcmae_ft_in1k
# convnextv2_huge.fcmae
# convnextv2_huge.fcmae_ft_in1k
# convnextv2_huge.fcmae_ft_in22k_in1k_384
# convnextv2_huge.fcmae_ft_in22k_in1k_512
# convnextv2_large.fcmae
# convnextv2_large.fcmae_ft_in1k
# convnextv2_large.fcmae_ft_in22k_in1k
# convnextv2_large.fcmae_ft_in22k_in1k_384
# convnextv2_nano.fcmae
# convnextv2_nano.fcmae_ft_in1k
# convnextv2_nano.fcmae_ft_in22k_in1k
# convnextv2_nano.fcmae_ft_in22k_in1k_384
# convnextv2_pico.fcmae
# convnextv2_pico.fcmae_ft_in1k
# convnextv2_tiny.fcmae
# convnextv2_tiny.fcmae_ft_in1k
# convnextv2_tiny.fcmae_ft_in22k_in1k
# convnextv2_tiny.fcmae_ft_in22k_in1k_384
# crossvit_9_240.in1k
# crossvit_9_dagger_240.in1k
# crossvit_15_240.in1k
# crossvit_15_dagger_240.in1k
# crossvit_15_dagger_408.in1k
# crossvit_18_240.in1k
# crossvit_18_dagger_240.in1k
# crossvit_18_dagger_408.in1k
# crossvit_base_240.in1k
# crossvit_small_240.in1k
# crossvit_tiny_240.in1k
# cs3darknet_focus_l.c2ns_in1k
# cs3darknet_focus_m.c2ns_in1k
# cs3darknet_focus_s.ra4_e3600_r256_in1k
# cs3darknet_l.c2ns_in1k
# cs3darknet_m.c2ns_in1k
# cs3darknet_x.c2ns_in1k
# cs3edgenet_x.c2_in1k
# cs3se_edgenet_x.c2ns_in1k
# cs3sedarknet_l.c2ns_in1k
# cs3sedarknet_x.c2ns_in1k
# cspdarknet53.ra_in1k
# cspresnet50.ra_in1k
# cspresnext50.ra_in1k
# darknet53.c2ns_in1k
# darknetaa53.c2ns_in1k
# davit_base.msft_in1k
# davit_base_fl.msft_florence2
# davit_huge_fl.msft_florence2
# davit_small.msft_in1k
# davit_tiny.msft_in1k
# deit3_base_patch16_224.fb_in1k
# deit3_base_patch16_224.fb_in22k_ft_in1k
# deit3_base_patch16_384.fb_in1k
# deit3_base_patch16_384.fb_in22k_ft_in1k
# deit3_huge_patch14_224.fb_in1k
# deit3_huge_patch14_224.fb_in22k_ft_in1k
# deit3_large_patch16_224.fb_in1k
# deit3_large_patch16_224.fb_in22k_ft_in1k
# deit3_large_patch16_384.fb_in1k
# deit3_large_patch16_384.fb_in22k_ft_in1k
# deit3_medium_patch16_224.fb_in1k
# deit3_medium_patch16_224.fb_in22k_ft_in1k
# deit3_small_patch16_224.fb_in1k
# deit3_small_patch16_224.fb_in22k_ft_in1k
# deit3_small_patch16_384.fb_in1k
# deit3_small_patch16_384.fb_in22k_ft_in1k
# deit_base_distilled_patch16_224.fb_in1k
# deit_base_distilled_patch16_384.fb_in1k
# deit_base_patch16_224.fb_in1k
# deit_base_patch16_384.fb_in1k
# deit_small_distilled_patch16_224.fb_in1k
# deit_small_patch16_224.fb_in1k
# deit_tiny_distilled_patch16_224.fb_in1k
# deit_tiny_patch16_224.fb_in1k
# densenet121.ra_in1k
# densenet121.tv_in1k
# densenet161.tv_in1k
# densenet169.tv_in1k
# densenet201.tv_in1k
# densenetblur121d.ra_in1k
# dla34.in1k
# dla46_c.in1k
# dla46x_c.in1k
# dla60.in1k
# dla60_res2net.in1k
# dla60_res2next.in1k
# dla60x.in1k
# dla60x_c.in1k
# dla102.in1k
# dla102x2.in1k
# dla102x.in1k
# dla169.in1k
# dm_nfnet_f0.dm_in1k
# dm_nfnet_f1.dm_in1k
# dm_nfnet_f2.dm_in1k
# dm_nfnet_f3.dm_in1k
# dm_nfnet_f4.dm_in1k
# dm_nfnet_f5.dm_in1k
# dm_nfnet_f6.dm_in1k
# dpn68.mx_in1k
# dpn68b.mx_in1k
# dpn68b.ra_in1k
# dpn92.mx_in1k
# dpn98.mx_in1k
# dpn107.mx_in1k
# dpn131.mx_in1k
# eca_botnext26ts_256.c1_in1k
# eca_halonext26ts.c1_in1k
# eca_nfnet_l0.ra2_in1k
# eca_nfnet_l1.ra2_in1k
# eca_nfnet_l2.ra3_in1k
# eca_resnet33ts.ra2_in1k
# eca_resnext26ts.ch_in1k
# ecaresnet26t.ra2_in1k
# ecaresnet50d.miil_in1k
# ecaresnet50d_pruned.miil_in1k
# ecaresnet50t.a1_in1k
# ecaresnet50t.a2_in1k
# ecaresnet50t.a3_in1k
# ecaresnet50t.ra2_in1k
# ecaresnet101d.miil_in1k
# ecaresnet101d_pruned.miil_in1k
# ecaresnet269d.ra2_in1k
# ecaresnetlight.miil_in1k
# edgenext_base.in21k_ft_in1k
# edgenext_base.usi_in1k
# edgenext_small.usi_in1k
# edgenext_small_rw.sw_in1k
# edgenext_x_small.in1k
# edgenext_xx_small.in1k
# efficientformer_l1.snap_dist_in1k
# efficientformer_l3.snap_dist_in1k
# efficientformer_l7.snap_dist_in1k
# efficientformerv2_l.snap_dist_in1k
# efficientformerv2_s0.snap_dist_in1k
# efficientformerv2_s1.snap_dist_in1k
# efficientformerv2_s2.snap_dist_in1k
# efficientnet_b0.ra4_e3600_r224_in1k
# efficientnet_b0.ra_in1k
# efficientnet_b1.ft_in1k
# efficientnet_b1.ra4_e3600_r240_in1k
# efficientnet_b1_pruned.in1k
# efficientnet_b2.ra_in1k
# efficientnet_b2_pruned.in1k
# efficientnet_b3.ra2_in1k
# efficientnet_b3_pruned.in1k
# efficientnet_b4.ra2_in1k
# efficientnet_b5.sw_in12k
# efficientnet_b5.sw_in12k_ft_in1k
# efficientnet_el.ra_in1k
# efficientnet_el_pruned.in1k
# efficientnet_em.ra2_in1k
# efficientnet_es.ra_in1k
# efficientnet_es_pruned.in1k
# efficientnet_lite0.ra_in1k
# efficientnetv2_rw_m.agc_in1k
# efficientnetv2_rw_s.ra2_in1k
# efficientnetv2_rw_t.ra2_in1k
# efficientvit_b0.r224_in1k
# efficientvit_b1.r224_in1k
# efficientvit_b1.r256_in1k
# efficientvit_b1.r288_in1k
# efficientvit_b2.r224_in1k
# efficientvit_b2.r256_in1k
# efficientvit_b2.r288_in1k
# efficientvit_b3.r224_in1k
# efficientvit_b3.r256_in1k
# efficientvit_b3.r288_in1k
# efficientvit_l1.r224_in1k
# efficientvit_l2.r224_in1k
# efficientvit_l2.r256_in1k
# efficientvit_l2.r288_in1k
# efficientvit_l2.r384_in1k
# efficientvit_l3.r224_in1k
# efficientvit_l3.r256_in1k
# efficientvit_l3.r320_in1k
# efficientvit_l3.r384_in1k
# efficientvit_m0.r224_in1k
# efficientvit_m1.r224_in1k
# efficientvit_m2.r224_in1k
# efficientvit_m3.r224_in1k
# efficientvit_m4.r224_in1k
# efficientvit_m5.r224_in1k
# ese_vovnet19b_dw.ra_in1k
# ese_vovnet39b.ra_in1k
# ese_vovnet57b.ra4_e3600_r256_in1k
# eva02_base_patch14_224.mim_in22k
# eva02_base_patch14_448.mim_in22k_ft_in1k
# eva02_base_patch14_448.mim_in22k_ft_in22k
# eva02_base_patch14_448.mim_in22k_ft_in22k_in1k
# eva02_base_patch16_clip_224.merged2b
# eva02_enormous_patch14_clip_224.laion2b
# eva02_enormous_patch14_clip_224.laion2b_plus
# eva02_large_patch14_224.mim_in22k
# eva02_large_patch14_224.mim_m38m
# eva02_large_patch14_448.mim_in22k_ft_in1k
# eva02_large_patch14_448.mim_in22k_ft_in22k
# eva02_large_patch14_448.mim_in22k_ft_in22k_in1k
# eva02_large_patch14_448.mim_m38m_ft_in1k
# eva02_large_patch14_448.mim_m38m_ft_in22k
# eva02_large_patch14_448.mim_m38m_ft_in22k_in1k
# eva02_large_patch14_clip_224.merged2b
# eva02_large_patch14_clip_336.merged2b
# eva02_small_patch14_224.mim_in22k
# eva02_small_patch14_336.mim_in22k_ft_in1k
# eva02_tiny_patch14_224.mim_in22k
# eva02_tiny_patch14_336.mim_in22k_ft_in1k
# eva_giant_patch14_224.clip_ft_in1k
# eva_giant_patch14_336.clip_ft_in1k
# eva_giant_patch14_336.m30m_ft_in22k_in1k
# eva_giant_patch14_560.m30m_ft_in22k_in1k
# eva_giant_patch14_clip_224.laion400m
# eva_giant_patch14_clip_224.merged2b
# eva_large_patch14_196.in22k_ft_in1k
# eva_large_patch14_196.in22k_ft_in22k_in1k
# eva_large_patch14_336.in22k_ft_in1k
# eva_large_patch14_336.in22k_ft_in22k_in1k
# fastvit_ma36.apple_dist_in1k
# fastvit_ma36.apple_in1k
# fastvit_mci0.apple_mclip
# fastvit_mci1.apple_mclip
# fastvit_mci2.apple_mclip
# fastvit_s12.apple_dist_in1k
# fastvit_s12.apple_in1k
# fastvit_sa12.apple_dist_in1k
# fastvit_sa12.apple_in1k
# fastvit_sa24.apple_dist_in1k
# fastvit_sa24.apple_in1k
# fastvit_sa36.apple_dist_in1k
# fastvit_sa36.apple_in1k
# fastvit_t8.apple_dist_in1k
# fastvit_t8.apple_in1k
# fastvit_t12.apple_dist_in1k
# fastvit_t12.apple_in1k
# fbnetc_100.rmsp_in1k
# fbnetv3_b.ra2_in1k
# fbnetv3_d.ra2_in1k
# fbnetv3_g.ra2_in1k
# flexivit_base.300ep_in1k
# flexivit_base.300ep_in21k
# flexivit_base.600ep_in1k
# flexivit_base.1000ep_in21k
# flexivit_base.1200ep_in1k
# flexivit_base.patch16_in21k
# flexivit_base.patch30_in21k
# flexivit_large.300ep_in1k
# flexivit_large.600ep_in1k
# flexivit_large.1200ep_in1k
# flexivit_small.300ep_in1k
# flexivit_small.600ep_in1k
# flexivit_small.1200ep_in1k
# focalnet_base_lrf.ms_in1k
# focalnet_base_srf.ms_in1k
# focalnet_huge_fl3.ms_in22k
# focalnet_huge_fl4.ms_in22k
# focalnet_large_fl3.ms_in22k
# focalnet_large_fl4.ms_in22k
# focalnet_small_lrf.ms_in1k
# focalnet_small_srf.ms_in1k
# focalnet_tiny_lrf.ms_in1k
# focalnet_tiny_srf.ms_in1k
# focalnet_xlarge_fl3.ms_in22k
# focalnet_xlarge_fl4.ms_in22k
# gc_efficientnetv2_rw_t.agc_in1k
# gcresnet33ts.ra2_in1k
# gcresnet50t.ra2_in1k
# gcresnext26ts.ch_in1k
# gcresnext50ts.ch_in1k
# gcvit_base.in1k
# gcvit_small.in1k
# gcvit_tiny.in1k
# gcvit_xtiny.in1k
# gcvit_xxtiny.in1k
# gernet_l.idstcv_in1k
# gernet_m.idstcv_in1k
# gernet_s.idstcv_in1k
# ghostnet_100.in1k
# ghostnetv2_100.in1k
# ghostnetv2_130.in1k
# ghostnetv2_160.in1k
# gmixer_24_224.ra3_in1k
# gmlp_s16_224.ra3_in1k
# halo2botnet50ts_256.a1h_in1k
# halonet26t.a1h_in1k
# halonet50ts.a1h_in1k
# haloregnetz_b.ra3_in1k
# hardcorenas_a.miil_green_in1k
# hardcorenas_b.miil_green_in1k
# hardcorenas_c.miil_green_in1k
# hardcorenas_d.miil_green_in1k
# hardcorenas_e.miil_green_in1k
# hardcorenas_f.miil_green_in1k
# hgnet_base.ssld_in1k
# hgnet_small.paddle_in1k
# hgnet_small.ssld_in1k
# hgnet_tiny.paddle_in1k
# hgnet_tiny.ssld_in1k
# hgnetv2_b0.ssld_stage1_in22k_in1k
# hgnetv2_b0.ssld_stage2_ft_in1k
# hgnetv2_b1.ssld_stage1_in22k_in1k
# hgnetv2_b1.ssld_stage2_ft_in1k
# hgnetv2_b2.ssld_stage1_in22k_in1k
# hgnetv2_b2.ssld_stage2_ft_in1k
# hgnetv2_b3.ssld_stage1_in22k_in1k
# hgnetv2_b3.ssld_stage2_ft_in1k
# hgnetv2_b4.ssld_stage1_in22k_in1k
# hgnetv2_b4.ssld_stage2_ft_in1k
# hgnetv2_b5.ssld_stage1_in22k_in1k
# hgnetv2_b5.ssld_stage2_ft_in1k
# hgnetv2_b6.ssld_stage1_in22k_in1k
# hgnetv2_b6.ssld_stage2_ft_in1k
# hiera_base_224.mae
# hiera_base_224.mae_in1k_ft_in1k
# hiera_base_plus_224.mae
# hiera_base_plus_224.mae_in1k_ft_in1k
# hiera_huge_224.mae
# hiera_huge_224.mae_in1k_ft_in1k
# hiera_large_224.mae
# hiera_large_224.mae_in1k_ft_in1k
# hiera_small_224.mae
# hiera_small_224.mae_in1k_ft_in1k
# hiera_small_abswin_256.sbb2_e200_in12k
# hiera_small_abswin_256.sbb2_e200_in12k_ft_in1k
# hiera_small_abswin_256.sbb2_pd_e200_in12k
# hiera_small_abswin_256.sbb2_pd_e200_in12k_ft_in1k
# hiera_tiny_224.mae
# hiera_tiny_224.mae_in1k_ft_in1k
# hrnet_w18.ms_aug_in1k
# hrnet_w18.ms_in1k
# hrnet_w18_small.gluon_in1k
# hrnet_w18_small.ms_in1k
# hrnet_w18_small_v2.gluon_in1k
# hrnet_w18_small_v2.ms_in1k
# hrnet_w18_ssld.paddle_in1k
# hrnet_w30.ms_in1k
# hrnet_w32.ms_in1k
# hrnet_w40.ms_in1k
# hrnet_w44.ms_in1k
# hrnet_w48.ms_in1k
# hrnet_w48_ssld.paddle_in1k
# hrnet_w64.ms_in1k
# inception_next_atto.sail_in1k
# inception_next_base.sail_in1k
# inception_next_base.sail_in1k_384
# inception_next_small.sail_in1k
# inception_next_tiny.sail_in1k
# inception_resnet_v2.tf_ens_adv_in1k
# inception_resnet_v2.tf_in1k
# inception_v3.gluon_in1k
# inception_v3.tf_adv_in1k
# inception_v3.tf_in1k
# inception_v3.tv_in1k
# inception_v4.tf_in1k
# lambda_resnet26rpt_256.c1_in1k
# lambda_resnet26t.c1_in1k
# lambda_resnet50ts.a1h_in1k
# lamhalobotnet50ts_256.a1h_in1k
# lcnet_050.ra2_in1k
# lcnet_075.ra2_in1k
# lcnet_100.ra2_in1k
# legacy_senet154.in1k
# legacy_seresnet18.in1k
# legacy_seresnet34.in1k
# legacy_seresnet50.in1k
# legacy_seresnet101.in1k
# legacy_seresnet152.in1k
# legacy_seresnext26_32x4d.in1k
# legacy_seresnext50_32x4d.in1k
# legacy_seresnext101_32x4d.in1k
# legacy_xception.tf_in1k
# levit_128.fb_dist_in1k
# levit_128s.fb_dist_in1k
# levit_192.fb_dist_in1k
# levit_256.fb_dist_in1k
# levit_384.fb_dist_in1k
# levit_conv_128.fb_dist_in1k
# levit_conv_128s.fb_dist_in1k
# levit_conv_192.fb_dist_in1k
# levit_conv_256.fb_dist_in1k
# levit_conv_384.fb_dist_in1k
# mambaout_base.in1k
# mambaout_base_plus_rw.sw_e150_in12k
# mambaout_base_plus_rw.sw_e150_in12k_ft_in1k
# mambaout_base_plus_rw.sw_e150_r384_in12k_ft_in1k
# mambaout_base_short_rw.sw_e500_in1k
# mambaout_base_tall_rw.sw_e500_in1k
# mambaout_base_wide_rw.sw_e500_in1k
# mambaout_femto.in1k
# mambaout_kobe.in1k
# mambaout_small.in1k
# mambaout_small_rw.sw_e450_in1k
# mambaout_tiny.in1k
# maxvit_base_tf_224.in1k
# maxvit_base_tf_224.in21k
# maxvit_base_tf_384.in1k
# maxvit_base_tf_384.in21k_ft_in1k
# maxvit_base_tf_512.in1k
# maxvit_base_tf_512.in21k_ft_in1k
# maxvit_large_tf_224.in1k
# maxvit_large_tf_224.in21k
# maxvit_large_tf_384.in1k
# maxvit_large_tf_384.in21k_ft_in1k
# maxvit_large_tf_512.in1k
# maxvit_large_tf_512.in21k_ft_in1k
# maxvit_nano_rw_256.sw_in1k
# maxvit_rmlp_base_rw_224.sw_in12k
# maxvit_rmlp_base_rw_224.sw_in12k_ft_in1k
# maxvit_rmlp_base_rw_384.sw_in12k_ft_in1k
# maxvit_rmlp_nano_rw_256.sw_in1k
# maxvit_rmlp_pico_rw_256.sw_in1k
# maxvit_rmlp_small_rw_224.sw_in1k
# maxvit_rmlp_tiny_rw_256.sw_in1k
# maxvit_small_tf_224.in1k
# maxvit_small_tf_384.in1k
# maxvit_small_tf_512.in1k
# maxvit_tiny_rw_224.sw_in1k
# maxvit_tiny_tf_224.in1k
# maxvit_tiny_tf_384.in1k
# maxvit_tiny_tf_512.in1k
# maxvit_xlarge_tf_224.in21k
# maxvit_xlarge_tf_384.in21k_ft_in1k
# maxvit_xlarge_tf_512.in21k_ft_in1k
# maxxvit_rmlp_nano_rw_256.sw_in1k
# maxxvit_rmlp_small_rw_256.sw_in1k
# maxxvitv2_nano_rw_256.sw_in1k
# maxxvitv2_rmlp_base_rw_224.sw_in12k
# maxxvitv2_rmlp_base_rw_224.sw_in12k_ft_in1k
# maxxvitv2_rmlp_base_rw_384.sw_in12k_ft_in1k
# mixer_b16_224.goog_in21k
# mixer_b16_224.goog_in21k_ft_in1k
# mixer_b16_224.miil_in21k
# mixer_b16_224.miil_in21k_ft_in1k
# mixer_l16_224.goog_in21k
# mixer_l16_224.goog_in21k_ft_in1k
# mixnet_l.ft_in1k
# mixnet_m.ft_in1k
# mixnet_s.ft_in1k
# mixnet_xl.ra_in1k
# mnasnet_100.rmsp_in1k
# mnasnet_small.lamb_in1k
# mobilenet_edgetpu_v2_m.ra4_e3600_r224_in1k
# mobilenetv1_100.ra4_e3600_r224_in1k
# mobilenetv1_100h.ra4_e3600_r224_in1k
# mobilenetv1_125.ra4_e3600_r224_in1k
# mobilenetv2_050.lamb_in1k
# mobilenetv2_100.ra_in1k
# mobilenetv2_110d.ra_in1k
# mobilenetv2_120d.ra_in1k
# mobilenetv2_140.ra_in1k
# mobilenetv3_large_100.miil_in21k
# mobilenetv3_large_100.miil_in21k_ft_in1k
# mobilenetv3_large_100.ra4_e3600_r224_in1k
# mobilenetv3_large_100.ra_in1k
# mobilenetv3_large_150d.ra4_e3600_r256_in1k
# mobilenetv3_rw.rmsp_in1k
# mobilenetv3_small_050.lamb_in1k
# mobilenetv3_small_075.lamb_in1k
# mobilenetv3_small_100.lamb_in1k
# mobilenetv4_conv_aa_large.e230_r384_in12k
# mobilenetv4_conv_aa_large.e230_r384_in12k_ft_in1k
# mobilenetv4_conv_aa_large.e230_r448_in12k_ft_in1k
# mobilenetv4_conv_aa_large.e600_r384_in1k
# mobilenetv4_conv_blur_medium.e500_r224_in1k
# mobilenetv4_conv_large.e500_r256_in1k
# mobilenetv4_conv_large.e600_r384_in1k
# mobilenetv4_conv_medium.e180_ad_r384_in12k
# mobilenetv4_conv_medium.e180_r384_in12k
# mobilenetv4_conv_medium.e250_r384_in12k
# mobilenetv4_conv_medium.e250_r384_in12k_ft_in1k
# mobilenetv4_conv_medium.e500_r224_in1k
# mobilenetv4_conv_medium.e500_r256_in1k
# mobilenetv4_conv_small.e1200_r224_in1k
# mobilenetv4_conv_small.e2400_r224_in1k
# mobilenetv4_conv_small.e3600_r256_in1k
# mobilenetv4_conv_small_050.e3000_r224_in1k
# mobilenetv4_hybrid_large.e600_r384_in1k
# mobilenetv4_hybrid_large.ix_e600_r384_in1k
# mobilenetv4_hybrid_medium.e200_r256_in12k
# mobilenetv4_hybrid_medium.e200_r256_in12k_ft_in1k
# mobilenetv4_hybrid_medium.e500_r224_in1k
# mobilenetv4_hybrid_medium.ix_e550_r256_in1k
# mobilenetv4_hybrid_medium.ix_e550_r384_in1k
# mobileone_s0.apple_in1k
# mobileone_s1.apple_in1k
# mobileone_s2.apple_in1k
# mobileone_s3.apple_in1k
# mobileone_s4.apple_in1k
# mobilevit_s.cvnets_in1k
# mobilevit_xs.cvnets_in1k
# mobilevit_xxs.cvnets_in1k
# mobilevitv2_050.cvnets_in1k
# mobilevitv2_075.cvnets_in1k
# mobilevitv2_100.cvnets_in1k
# mobilevitv2_125.cvnets_in1k
# mobilevitv2_150.cvnets_in1k
# mobilevitv2_150.cvnets_in22k_ft_in1k
# mobilevitv2_150.cvnets_in22k_ft_in1k_384
# mobilevitv2_175.cvnets_in1k
# mobilevitv2_175.cvnets_in22k_ft_in1k
# mobilevitv2_175.cvnets_in22k_ft_in1k_384
# mobilevitv2_200.cvnets_in1k
# mobilevitv2_200.cvnets_in22k_ft_in1k
# mobilevitv2_200.cvnets_in22k_ft_in1k_384
# mvitv2_base.fb_in1k
# mvitv2_base_cls.fb_inw21k
# mvitv2_huge_cls.fb_inw21k
# mvitv2_large.fb_in1k
# mvitv2_large_cls.fb_inw21k
# mvitv2_small.fb_in1k
# mvitv2_tiny.fb_in1k
# nasnetalarge.tf_in1k
# nest_base_jx.goog_in1k
# nest_small_jx.goog_in1k
# nest_tiny_jx.goog_in1k
# nextvit_base.bd_in1k
# nextvit_base.bd_in1k_384
# nextvit_base.bd_ssld_6m_in1k
# nextvit_base.bd_ssld_6m_in1k_384
# nextvit_large.bd_in1k
# nextvit_large.bd_in1k_384
# nextvit_large.bd_ssld_6m_in1k
# nextvit_large.bd_ssld_6m_in1k_384
# nextvit_small.bd_in1k
# nextvit_small.bd_in1k_384
# nextvit_small.bd_ssld_6m_in1k
# nextvit_small.bd_ssld_6m_in1k_384
# nf_regnet_b1.ra2_in1k
# nf_resnet50.ra2_in1k
# nfnet_l0.ra2_in1k
# pit_b_224.in1k
# pit_b_distilled_224.in1k
# pit_s_224.in1k
# pit_s_distilled_224.in1k
# pit_ti_224.in1k
# pit_ti_distilled_224.in1k
# pit_xs_224.in1k
# pit_xs_distilled_224.in1k
# pnasnet5large.tf_in1k
# poolformer_m36.sail_in1k
# poolformer_m48.sail_in1k
# poolformer_s12.sail_in1k
# poolformer_s24.sail_in1k
# poolformer_s36.sail_in1k
# poolformerv2_m36.sail_in1k
# poolformerv2_m48.sail_in1k
# poolformerv2_s12.sail_in1k
# poolformerv2_s24.sail_in1k
# poolformerv2_s36.sail_in1k
# pvt_v2_b0.in1k
# pvt_v2_b1.in1k
# pvt_v2_b2.in1k
# pvt_v2_b2_li.in1k
# pvt_v2_b3.in1k
# pvt_v2_b4.in1k
# pvt_v2_b5.in1k
# rdnet_base.nv_in1k
# rdnet_large.nv_in1k
# rdnet_large.nv_in1k_ft_in1k_384
# rdnet_small.nv_in1k
# rdnet_tiny.nv_in1k
# regnetv_040.ra3_in1k
# regnetv_064.ra3_in1k
# regnetx_002.pycls_in1k
# regnetx_004.pycls_in1k
# regnetx_004_tv.tv2_in1k
# regnetx_006.pycls_in1k
# regnetx_008.pycls_in1k
# regnetx_008.tv2_in1k
# regnetx_016.pycls_in1k
# regnetx_016.tv2_in1k
# regnetx_032.pycls_in1k
# regnetx_032.tv2_in1k
# regnetx_040.pycls_in1k
# regnetx_064.pycls_in1k
# regnetx_080.pycls_in1k
# regnetx_080.tv2_in1k
# regnetx_120.pycls_in1k
# regnetx_160.pycls_in1k
# regnetx_160.tv2_in1k
# regnetx_320.pycls_in1k
# regnetx_320.tv2_in1k
# regnety_002.pycls_in1k
# regnety_004.pycls_in1k
# regnety_004.tv2_in1k
# regnety_006.pycls_in1k
# regnety_008.pycls_in1k
# regnety_008_tv.tv2_in1k
# regnety_016.pycls_in1k
# regnety_016.tv2_in1k
# regnety_032.pycls_in1k
# regnety_032.ra_in1k
# regnety_032.tv2_in1k
# regnety_040.pycls_in1k
# regnety_040.ra3_in1k
# regnety_064.pycls_in1k
# regnety_064.ra3_in1k
# regnety_080.pycls_in1k
# regnety_080.ra3_in1k
# regnety_080_tv.tv2_in1k
# regnety_120.pycls_in1k
# regnety_120.sw_in12k
# regnety_120.sw_in12k_ft_in1k
# regnety_160.deit_in1k
# regnety_160.lion_in12k_ft_in1k
# regnety_160.pycls_in1k
# regnety_160.sw_in12k
# regnety_160.sw_in12k_ft_in1k
# regnety_160.swag_ft_in1k
# regnety_160.swag_lc_in1k
# regnety_160.tv2_in1k
# regnety_320.pycls_in1k
# regnety_320.seer
# regnety_320.seer_ft_in1k
# regnety_320.swag_ft_in1k
# regnety_320.swag_lc_in1k
# regnety_320.tv2_in1k
# regnety_640.seer
# regnety_640.seer_ft_in1k
# regnety_1280.seer
# regnety_1280.seer_ft_in1k
# regnety_1280.swag_ft_in1k
# regnety_1280.swag_lc_in1k
# regnety_2560.seer_ft_in1k
# regnetz_040.ra3_in1k
# regnetz_040_h.ra3_in1k
# regnetz_b16.ra3_in1k
# regnetz_c16.ra3_in1k
# regnetz_c16_evos.ch_in1k
# regnetz_d8.ra3_in1k
# regnetz_d8_evos.ch_in1k
# regnetz_d32.ra3_in1k
# regnetz_e8.ra3_in1k
# repghostnet_050.in1k
# repghostnet_058.in1k
# repghostnet_080.in1k
# repghostnet_100.in1k
# repghostnet_111.in1k
# repghostnet_130.in1k
# repghostnet_150.in1k
# repghostnet_200.in1k
# repvgg_a0.rvgg_in1k
# repvgg_a1.rvgg_in1k
# repvgg_a2.rvgg_in1k
# repvgg_b0.rvgg_in1k
# repvgg_b1.rvgg_in1k
# repvgg_b1g4.rvgg_in1k
# repvgg_b2.rvgg_in1k
# repvgg_b2g4.rvgg_in1k
# repvgg_b3.rvgg_in1k
# repvgg_b3g4.rvgg_in1k
# repvgg_d2se.rvgg_in1k
# repvit_m0_9.dist_300e_in1k
# repvit_m0_9.dist_450e_in1k
# repvit_m1.dist_in1k
# repvit_m1_0.dist_300e_in1k
# repvit_m1_0.dist_450e_in1k
# repvit_m1_1.dist_300e_in1k
# repvit_m1_1.dist_450e_in1k
# repvit_m1_5.dist_300e_in1k
# repvit_m1_5.dist_450e_in1k
# repvit_m2.dist_in1k
# repvit_m2_3.dist_300e_in1k
# repvit_m2_3.dist_450e_in1k
# repvit_m3.dist_in1k
# res2net50_14w_8s.in1k
# res2net50_26w_4s.in1k
# res2net50_26w_6s.in1k
# res2net50_26w_8s.in1k
# res2net50_48w_2s.in1k
# res2net50d.in1k
# res2net101_26w_4s.in1k
# res2net101d.in1k
# res2next50.in1k
# resmlp_12_224.fb_dino
# resmlp_12_224.fb_distilled_in1k
# resmlp_12_224.fb_in1k
# resmlp_24_224.fb_dino
# resmlp_24_224.fb_distilled_in1k
# resmlp_24_224.fb_in1k
# resmlp_36_224.fb_distilled_in1k
# resmlp_36_224.fb_in1k
# resmlp_big_24_224.fb_distilled_in1k
# resmlp_big_24_224.fb_in1k
# resmlp_big_24_224.fb_in22k_ft_in1k
# resnest14d.gluon_in1k
# resnest26d.gluon_in1k
# resnest50d.in1k
# resnest50d_1s4x24d.in1k
# resnest50d_4s2x40d.in1k
# resnest101e.in1k
# resnest200e.in1k
# resnest269e.in1k
# resnet10t.c3_in1k
# resnet14t.c3_in1k
# resnet18.a1_in1k
# resnet18.a2_in1k
# resnet18.a3_in1k
# resnet18.fb_ssl_yfcc100m_ft_in1k
# resnet18.fb_swsl_ig1b_ft_in1k
# resnet18.gluon_in1k
# resnet18.tv_in1k
# resnet18d.ra2_in1k
# resnet18d.ra4_e3600_r224_in1k
# resnet26.bt_in1k
# resnet26d.bt_in1k
# resnet26t.ra2_in1k
# resnet32ts.ra2_in1k
# resnet33ts.ra2_in1k
# resnet34.a1_in1k
# resnet34.a2_in1k
# resnet34.a3_in1k
# resnet34.bt_in1k
# resnet34.gluon_in1k
# resnet34.ra4_e3600_r224_in1k
# resnet34.tv_in1k
# resnet34d.ra2_in1k
# resnet50.a1_in1k
# resnet50.a1h_in1k
# resnet50.a2_in1k
# resnet50.a3_in1k
# resnet50.am_in1k
# resnet50.b1k_in1k
# resnet50.b2k_in1k
# resnet50.bt_in1k
# resnet50.c1_in1k
# resnet50.c2_in1k
# resnet50.d_in1k
# resnet50.fb_ssl_yfcc100m_ft_in1k
# resnet50.fb_swsl_ig1b_ft_in1k
# resnet50.gluon_in1k
# resnet50.ra_in1k
# resnet50.ram_in1k
# resnet50.tv2_in1k
# resnet50.tv_in1k
# resnet50_clip.cc12m
# resnet50_clip.openai
# resnet50_clip.yfcc15m
# resnet50_clip_gap.cc12m
# resnet50_clip_gap.openai
# resnet50_clip_gap.yfcc15m
# resnet50_gn.a1h_in1k
# resnet50c.gluon_in1k
# resnet50d.a1_in1k
# resnet50d.a2_in1k
# resnet50d.a3_in1k
# resnet50d.gluon_in1k
# resnet50d.ra2_in1k
# resnet50d.ra4_e3600_r224_in1k
# resnet50s.gluon_in1k
# resnet50x4_clip.openai
# resnet50x4_clip_gap.openai
# resnet50x16_clip.openai
# resnet50x16_clip_gap.openai
# resnet50x64_clip.openai
# resnet50x64_clip_gap.openai
# resnet51q.ra2_in1k
# resnet61q.ra2_in1k
# resnet101.a1_in1k
# resnet101.a1h_in1k
# resnet101.a2_in1k
# resnet101.a3_in1k
# resnet101.gluon_in1k
# resnet101.tv2_in1k
# resnet101.tv_in1k
# resnet101_clip.openai
# resnet101_clip.yfcc15m
# resnet101_clip_gap.openai
# resnet101_clip_gap.yfcc15m
# resnet101c.gluon_in1k
# resnet101d.gluon_in1k
# resnet101d.ra2_in1k
# resnet101s.gluon_in1k
# resnet152.a1_in1k
# resnet152.a1h_in1k
# resnet152.a2_in1k
# resnet152.a3_in1k
# resnet152.gluon_in1k
# resnet152.tv2_in1k
# resnet152.tv_in1k
# resnet152c.gluon_in1k
# resnet152d.gluon_in1k
# resnet152d.ra2_in1k
# resnet152s.gluon_in1k
# resnet200d.ra2_in1k
# resnetaa50.a1h_in1k
# resnetaa50d.d_in12k
# resnetaa50d.sw_in12k
# resnetaa50d.sw_in12k_ft_in1k
# resnetaa101d.sw_in12k
# resnetaa101d.sw_in12k_ft_in1k
# resnetblur50.bt_in1k
# resnetrs50.tf_in1k
# resnetrs101.tf_in1k
# resnetrs152.tf_in1k
# resnetrs200.tf_in1k
# resnetrs270.tf_in1k
# resnetrs350.tf_in1k
# resnetrs420.tf_in1k
# resnetv2_18.ra4_e3600_r224_in1k
# resnetv2_18d.ra4_e3600_r224_in1k
# resnetv2_34.ra4_e3600_r224_in1k
# resnetv2_34d.ra4_e3600_r224_in1k
# resnetv2_34d.ra4_e3600_r384_in1k
# resnetv2_50.a1h_in1k
# resnetv2_50d_evos.ah_in1k
# resnetv2_50d_gn.ah_in1k
# resnetv2_50x1_bit.goog_distilled_in1k
# resnetv2_50x1_bit.goog_in21k
# resnetv2_50x1_bit.goog_in21k_ft_in1k
# resnetv2_50x3_bit.goog_in21k
# resnetv2_50x3_bit.goog_in21k_ft_in1k
# resnetv2_101.a1h_in1k
# resnetv2_101x1_bit.goog_in21k
# resnetv2_101x1_bit.goog_in21k_ft_in1k
# resnetv2_101x3_bit.goog_in21k
# resnetv2_101x3_bit.goog_in21k_ft_in1k
# resnetv2_152x2_bit.goog_in21k
# resnetv2_152x2_bit.goog_in21k_ft_in1k
# resnetv2_152x2_bit.goog_teacher_in21k_ft_in1k
# resnetv2_152x2_bit.goog_teacher_in21k_ft_in1k_384
# resnetv2_152x4_bit.goog_in21k
# resnetv2_152x4_bit.goog_in21k_ft_in1k
# resnext26ts.ra2_in1k
# resnext50_32x4d.a1_in1k
# resnext50_32x4d.a1h_in1k
# resnext50_32x4d.a2_in1k
# resnext50_32x4d.a3_in1k
# resnext50_32x4d.fb_ssl_yfcc100m_ft_in1k
# resnext50_32x4d.fb_swsl_ig1b_ft_in1k
# resnext50_32x4d.gluon_in1k
# resnext50_32x4d.ra_in1k
# resnext50_32x4d.tv2_in1k
# resnext50_32x4d.tv_in1k
# resnext50d_32x4d.bt_in1k
# resnext101_32x4d.fb_ssl_yfcc100m_ft_in1k
# resnext101_32x4d.fb_swsl_ig1b_ft_in1k
# resnext101_32x4d.gluon_in1k
# resnext101_32x8d.fb_ssl_yfcc100m_ft_in1k
# resnext101_32x8d.fb_swsl_ig1b_ft_in1k
# resnext101_32x8d.fb_wsl_ig1b_ft_in1k
# resnext101_32x8d.tv2_in1k
# resnext101_32x8d.tv_in1k
# resnext101_32x16d.fb_ssl_yfcc100m_ft_in1k
# resnext101_32x16d.fb_swsl_ig1b_ft_in1k
# resnext101_32x16d.fb_wsl_ig1b_ft_in1k
# resnext101_32x32d.fb_wsl_ig1b_ft_in1k
# resnext101_64x4d.c1_in1k
# resnext101_64x4d.gluon_in1k
# resnext101_64x4d.tv_in1k
# rexnet_100.nav_in1k
# rexnet_130.nav_in1k
# rexnet_150.nav_in1k
# rexnet_200.nav_in1k
# rexnet_300.nav_in1k
# rexnetr_200.sw_in12k
# rexnetr_200.sw_in12k_ft_in1k
# rexnetr_300.sw_in12k
# rexnetr_300.sw_in12k_ft_in1k
# sam2_hiera_base_plus.fb_r896
# sam2_hiera_base_plus.fb_r896_2pt1
# sam2_hiera_large.fb_r1024
# sam2_hiera_large.fb_r1024_2pt1
# sam2_hiera_small.fb_r896
# sam2_hiera_small.fb_r896_2pt1
# sam2_hiera_tiny.fb_r896
# sam2_hiera_tiny.fb_r896_2pt1
# samvit_base_patch16.sa1b
# samvit_huge_patch16.sa1b
# samvit_large_patch16.sa1b
# sebotnet33ts_256.a1h_in1k
# sehalonet33ts.ra2_in1k
# selecsls42b.in1k
# selecsls60.in1k
# selecsls60b.in1k
# semnasnet_075.rmsp_in1k
# semnasnet_100.rmsp_in1k
# senet154.gluon_in1k
# sequencer2d_l.in1k
# sequencer2d_m.in1k
# sequencer2d_s.in1k
# seresnet33ts.ra2_in1k
# seresnet50.a1_in1k
# seresnet50.a2_in1k
# seresnet50.a3_in1k
# seresnet50.ra2_in1k
# seresnet152d.ra2_in1k
# seresnext26d_32x4d.bt_in1k
# seresnext26t_32x4d.bt_in1k
# seresnext26ts.ch_in1k
# seresnext50_32x4d.gluon_in1k
# seresnext50_32x4d.racm_in1k
# seresnext101_32x4d.gluon_in1k
# seresnext101_32x8d.ah_in1k
# seresnext101_64x4d.gluon_in1k
# seresnext101d_32x8d.ah_in1k
# seresnextaa101d_32x8d.ah_in1k
# seresnextaa101d_32x8d.sw_in12k
# seresnextaa101d_32x8d.sw_in12k_ft_in1k
# seresnextaa101d_32x8d.sw_in12k_ft_in1k_288
# seresnextaa201d_32x8d.sw_in12k
# seresnextaa201d_32x8d.sw_in12k_ft_in1k_384
# skresnet18.ra_in1k
# skresnet34.ra_in1k
# skresnext50_32x4d.ra_in1k
# spnasnet_100.rmsp_in1k
# swin_base_patch4_window7_224.ms_in1k
# swin_base_patch4_window7_224.ms_in22k
# swin_base_patch4_window7_224.ms_in22k_ft_in1k
# swin_base_patch4_window12_384.ms_in1k
# swin_base_patch4_window12_384.ms_in22k
# swin_base_patch4_window12_384.ms_in22k_ft_in1k
# swin_large_patch4_window7_224.ms_in22k
# swin_large_patch4_window7_224.ms_in22k_ft_in1k
# swin_large_patch4_window12_384.ms_in22k
# swin_large_patch4_window12_384.ms_in22k_ft_in1k
# swin_s3_base_224.ms_in1k
# swin_s3_small_224.ms_in1k
# swin_s3_tiny_224.ms_in1k
# swin_small_patch4_window7_224.ms_in1k
# swin_small_patch4_window7_224.ms_in22k
# swin_small_patch4_window7_224.ms_in22k_ft_in1k
# swin_tiny_patch4_window7_224.ms_in1k
# swin_tiny_patch4_window7_224.ms_in22k
# swin_tiny_patch4_window7_224.ms_in22k_ft_in1k
# swinv2_base_window8_256.ms_in1k
# swinv2_base_window12_192.ms_in22k
# swinv2_base_window12to16_192to256.ms_in22k_ft_in1k
# swinv2_base_window12to24_192to384.ms_in22k_ft_in1k
# swinv2_base_window16_256.ms_in1k
# swinv2_cr_small_224.sw_in1k
# swinv2_cr_small_ns_224.sw_in1k
# swinv2_cr_tiny_ns_224.sw_in1k
# swinv2_large_window12_192.ms_in22k
# swinv2_large_window12to16_192to256.ms_in22k_ft_in1k
# swinv2_large_window12to24_192to384.ms_in22k_ft_in1k
# swinv2_small_window8_256.ms_in1k
# swinv2_small_window16_256.ms_in1k
# swinv2_tiny_window8_256.ms_in1k
# swinv2_tiny_window16_256.ms_in1k
# test_byobnet.r160_in1k
# test_convnext2.r160_in1k
# test_convnext3.r160_in1k
# test_convnext.r160_in1k
# test_efficientnet.r160_in1k
# test_efficientnet_evos.r160_in1k
# test_efficientnet_gn.r160_in1k
# test_efficientnet_ln.r160_in1k
# test_nfnet.r160_in1k
# test_resnet.r160_in1k
# test_vit2.r160_in1k
# test_vit3.r160_in1k
# test_vit.r160_in1k
# tf_efficientnet_b0.aa_in1k
# tf_efficientnet_b0.ap_in1k
# tf_efficientnet_b0.in1k
# tf_efficientnet_b0.ns_jft_in1k
# tf_efficientnet_b1.aa_in1k
# tf_efficientnet_b1.ap_in1k
# tf_efficientnet_b1.in1k
# tf_efficientnet_b1.ns_jft_in1k
# tf_efficientnet_b2.aa_in1k
# tf_efficientnet_b2.ap_in1k
# tf_efficientnet_b2.in1k
# tf_efficientnet_b2.ns_jft_in1k
# tf_efficientnet_b3.aa_in1k
# tf_efficientnet_b3.ap_in1k
# tf_efficientnet_b3.in1k
# tf_efficientnet_b3.ns_jft_in1k
# tf_efficientnet_b4.aa_in1k
# tf_efficientnet_b4.ap_in1k
# tf_efficientnet_b4.in1k
# tf_efficientnet_b4.ns_jft_in1k
# tf_efficientnet_b5.aa_in1k
# tf_efficientnet_b5.ap_in1k
# tf_efficientnet_b5.in1k
# tf_efficientnet_b5.ns_jft_in1k
# tf_efficientnet_b5.ra_in1k
# tf_efficientnet_b6.aa_in1k
# tf_efficientnet_b6.ap_in1k
# tf_efficientnet_b6.ns_jft_in1k
# tf_efficientnet_b7.aa_in1k
# tf_efficientnet_b7.ap_in1k
# tf_efficientnet_b7.ns_jft_in1k
# tf_efficientnet_b7.ra_in1k
# tf_efficientnet_b8.ap_in1k
# tf_efficientnet_b8.ra_in1k
# tf_efficientnet_cc_b0_4e.in1k
# tf_efficientnet_cc_b0_8e.in1k
# tf_efficientnet_cc_b1_8e.in1k
# tf_efficientnet_el.in1k
# tf_efficientnet_em.in1k
# tf_efficientnet_es.in1k
# tf_efficientnet_l2.ns_jft_in1k
# tf_efficientnet_l2.ns_jft_in1k_475
# tf_efficientnet_lite0.in1k
# tf_efficientnet_lite1.in1k
# tf_efficientnet_lite2.in1k
# tf_efficientnet_lite3.in1k
# tf_efficientnet_lite4.in1k
# tf_efficientnetv2_b0.in1k
# tf_efficientnetv2_b1.in1k
# tf_efficientnetv2_b2.in1k
# tf_efficientnetv2_b3.in1k
# tf_efficientnetv2_b3.in21k
# tf_efficientnetv2_b3.in21k_ft_in1k
# tf_efficientnetv2_l.in1k
# tf_efficientnetv2_l.in21k
# tf_efficientnetv2_l.in21k_ft_in1k
# tf_efficientnetv2_m.in1k
# tf_efficientnetv2_m.in21k
# tf_efficientnetv2_m.in21k_ft_in1k
# tf_efficientnetv2_s.in1k
# tf_efficientnetv2_s.in21k
# tf_efficientnetv2_s.in21k_ft_in1k
# tf_efficientnetv2_xl.in21k
# tf_efficientnetv2_xl.in21k_ft_in1k
# tf_mixnet_l.in1k
# tf_mixnet_m.in1k
# tf_mixnet_s.in1k
# tf_mobilenetv3_large_075.in1k
# tf_mobilenetv3_large_100.in1k
# tf_mobilenetv3_large_minimal_100.in1k
# tf_mobilenetv3_small_075.in1k
# tf_mobilenetv3_small_100.in1k
# tf_mobilenetv3_small_minimal_100.in1k
# tiny_vit_5m_224.dist_in22k
# tiny_vit_5m_224.dist_in22k_ft_in1k
# tiny_vit_5m_224.in1k
# tiny_vit_11m_224.dist_in22k
# tiny_vit_11m_224.dist_in22k_ft_in1k
# tiny_vit_11m_224.in1k
# tiny_vit_21m_224.dist_in22k
# tiny_vit_21m_224.dist_in22k_ft_in1k
# tiny_vit_21m_224.in1k
# tiny_vit_21m_384.dist_in22k_ft_in1k
# tiny_vit_21m_512.dist_in22k_ft_in1k
# tinynet_a.in1k
# tinynet_b.in1k
# tinynet_c.in1k
# tinynet_d.in1k
# tinynet_e.in1k
# tnt_s_patch16_224
# tresnet_l.miil_in1k
# tresnet_l.miil_in1k_448
# tresnet_m.miil_in1k
# tresnet_m.miil_in1k_448
# tresnet_m.miil_in21k
# tresnet_m.miil_in21k_ft_in1k
# tresnet_v2_l.miil_in21k
# tresnet_v2_l.miil_in21k_ft_in1k
# tresnet_xl.miil_in1k
# tresnet_xl.miil_in1k_448
# twins_pcpvt_base.in1k
# twins_pcpvt_large.in1k
# twins_pcpvt_small.in1k
# twins_svt_base.in1k
# twins_svt_large.in1k
# twins_svt_small.in1k
# vgg11.tv_in1k
# vgg11_bn.tv_in1k
# vgg13.tv_in1k
# vgg13_bn.tv_in1k
# vgg16.tv_in1k
# vgg16_bn.tv_in1k
# vgg19.tv_in1k
# vgg19_bn.tv_in1k
# visformer_small.in1k
# visformer_tiny.in1k
# vit_base_mci_224.apple_mclip
# vit_base_mci_224.apple_mclip_lt
# vit_base_patch8_224.augreg2_in21k_ft_in1k
# vit_base_patch8_224.augreg_in21k
# vit_base_patch8_224.augreg_in21k_ft_in1k
# vit_base_patch8_224.dino
# vit_base_patch14_dinov2.lvd142m
# vit_base_patch14_reg4_dinov2.lvd142m
# vit_base_patch16_224.augreg2_in21k_ft_in1k
# vit_base_patch16_224.augreg_in1k
# vit_base_patch16_224.augreg_in21k
# vit_base_patch16_224.augreg_in21k_ft_in1k
# vit_base_patch16_224.dino
# vit_base_patch16_224.mae
# vit_base_patch16_224.orig_in21k
# vit_base_patch16_224.orig_in21k_ft_in1k
# vit_base_patch16_224.sam_in1k
# vit_base_patch16_224_miil.in21k
# vit_base_patch16_224_miil.in21k_ft_in1k
# vit_base_patch16_384.augreg_in1k
# vit_base_patch16_384.augreg_in21k_ft_in1k
# vit_base_patch16_384.orig_in21k_ft_in1k
# vit_base_patch16_clip_224.datacompxl
# vit_base_patch16_clip_224.dfn2b
# vit_base_patch16_clip_224.laion2b
# vit_base_patch16_clip_224.laion2b_ft_in1k
# vit_base_patch16_clip_224.laion2b_ft_in12k
# vit_base_patch16_clip_224.laion2b_ft_in12k_in1k
# vit_base_patch16_clip_224.laion400m_e32
# vit_base_patch16_clip_224.metaclip_2pt5b
# vit_base_patch16_clip_224.metaclip_400m
# vit_base_patch16_clip_224.openai
# vit_base_patch16_clip_224.openai_ft_in1k
# vit_base_patch16_clip_224.openai_ft_in12k
# vit_base_patch16_clip_224.openai_ft_in12k_in1k
# vit_base_patch16_clip_384.laion2b_ft_in1k
# vit_base_patch16_clip_384.laion2b_ft_in12k_in1k
# vit_base_patch16_clip_384.openai_ft_in1k
# vit_base_patch16_clip_384.openai_ft_in12k_in1k
# vit_base_patch16_clip_quickgelu_224.metaclip_2pt5b
# vit_base_patch16_clip_quickgelu_224.metaclip_400m
# vit_base_patch16_clip_quickgelu_224.openai
# vit_base_patch16_plus_clip_240.laion400m_e32
# vit_base_patch16_rope_reg1_gap_256.sbb_in1k
# vit_base_patch16_rpn_224.sw_in1k
# vit_base_patch16_siglip_224.v2_webli
# vit_base_patch16_siglip_224.webli
# vit_base_patch16_siglip_256.v2_webli
# vit_base_patch16_siglip_256.webli
# vit_base_patch16_siglip_256.webli_i18n
# vit_base_patch16_siglip_384.v2_webli
# vit_base_patch16_siglip_384.webli
# vit_base_patch16_siglip_512.v2_webli
# vit_base_patch16_siglip_512.webli
# vit_base_patch16_siglip_gap_224.v2_webli
# vit_base_patch16_siglip_gap_224.webli
# vit_base_patch16_siglip_gap_256.v2_webli
# vit_base_patch16_siglip_gap_256.webli
# vit_base_patch16_siglip_gap_256.webli_i18n
# vit_base_patch16_siglip_gap_384.v2_webli
# vit_base_patch16_siglip_gap_384.webli
# vit_base_patch16_siglip_gap_512.v2_webli
# vit_base_patch16_siglip_gap_512.webli
# vit_base_patch32_224.augreg_in1k
# vit_base_patch32_224.augreg_in21k
# vit_base_patch32_224.augreg_in21k_ft_in1k
# vit_base_patch32_224.orig_in21k
# vit_base_patch32_224.sam_in1k
# vit_base_patch32_384.augreg_in1k
# vit_base_patch32_384.augreg_in21k_ft_in1k
# vit_base_patch32_clip_224.datacompxl
# vit_base_patch32_clip_224.laion2b
# vit_base_patch32_clip_224.laion2b_ft_in1k
# vit_base_patch32_clip_224.laion2b_ft_in12k_in1k
# vit_base_patch32_clip_224.laion400m_e32
# vit_base_patch32_clip_224.metaclip_2pt5b
# vit_base_patch32_clip_224.metaclip_400m
# vit_base_patch32_clip_224.openai
# vit_base_patch32_clip_224.openai_ft_in1k
# vit_base_patch32_clip_256.datacompxl
# vit_base_patch32_clip_384.laion2b_ft_in12k_in1k
# vit_base_patch32_clip_384.openai_ft_in12k_in1k
# vit_base_patch32_clip_448.laion2b_ft_in12k_in1k
# vit_base_patch32_clip_quickgelu_224.laion400m_e32
# vit_base_patch32_clip_quickgelu_224.metaclip_2pt5b
# vit_base_patch32_clip_quickgelu_224.metaclip_400m
# vit_base_patch32_clip_quickgelu_224.openai
# vit_base_patch32_siglip_256.v2_webli
# vit_base_patch32_siglip_gap_256.v2_webli
# vit_base_r50_s16_224.orig_in21k
# vit_base_r50_s16_384.orig_in21k_ft_in1k
# vit_betwixt_patch16_reg1_gap_256.sbb_in1k
# vit_betwixt_patch16_reg4_gap_256.sbb2_e200_in12k
# vit_betwixt_patch16_reg4_gap_256.sbb2_e200_in12k_ft_in1k
# vit_betwixt_patch16_reg4_gap_256.sbb_in1k
# vit_betwixt_patch16_reg4_gap_256.sbb_in12k
# vit_betwixt_patch16_reg4_gap_256.sbb_in12k_ft_in1k
# vit_betwixt_patch16_reg4_gap_384.sbb2_e200_in12k_ft_in1k
# vit_betwixt_patch16_rope_reg4_gap_256.sbb_in1k
# vit_betwixt_patch32_clip_224.tinyclip_laion400m
# vit_giant_patch14_clip_224.laion2b
# vit_giant_patch14_dinov2.lvd142m
# vit_giant_patch14_reg4_dinov2.lvd142m
# vit_giant_patch16_gap_224.in22k_ijepa
# vit_giantopt_patch16_siglip_256.v2_webli
# vit_giantopt_patch16_siglip_384.v2_webli
# vit_giantopt_patch16_siglip_gap_256.v2_webli
# vit_giantopt_patch16_siglip_gap_384.v2_webli
# vit_gigantic_patch14_clip_224.laion2b
# vit_gigantic_patch14_clip_224.metaclip_2pt5b
# vit_gigantic_patch14_clip_quickgelu_224.metaclip_2pt5b
# vit_huge_patch14_224.mae
# vit_huge_patch14_224.orig_in21k
# vit_huge_patch14_clip_224.dfn5b
# vit_huge_patch14_clip_224.laion2b
# vit_huge_patch14_clip_224.laion2b_ft_in1k
# vit_huge_patch14_clip_224.laion2b_ft_in12k
# vit_huge_patch14_clip_224.laion2b_ft_in12k_in1k
# vit_huge_patch14_clip_224.metaclip_2pt5b
# vit_huge_patch14_clip_224.metaclip_altogether
# vit_huge_patch14_clip_336.laion2b_ft_in12k_in1k
# vit_huge_patch14_clip_378.dfn5b
# vit_huge_patch14_clip_quickgelu_224.dfn5b
# vit_huge_patch14_clip_quickgelu_224.metaclip_2pt5b
# vit_huge_patch14_clip_quickgelu_378.dfn5b
# vit_huge_patch14_gap_224.in1k_ijepa
# vit_huge_patch14_gap_224.in22k_ijepa
# vit_huge_patch16_gap_448.in1k_ijepa
# vit_intern300m_patch14_448.ogvl_2pt5
# vit_intern300m_patch14_448.ogvl_dist
# vit_large_patch14_clip_224.datacompxl
# vit_large_patch14_clip_224.dfn2b
# vit_large_patch14_clip_224.dfn2b_s39b
# vit_large_patch14_clip_224.laion2b
# vit_large_patch14_clip_224.laion2b_ft_in1k
# vit_large_patch14_clip_224.laion2b_ft_in12k
# vit_large_patch14_clip_224.laion2b_ft_in12k_in1k
# vit_large_patch14_clip_224.laion400m_e32
# vit_large_patch14_clip_224.metaclip_2pt5b
# vit_large_patch14_clip_224.metaclip_400m
# vit_large_patch14_clip_224.openai
# vit_large_patch14_clip_224.openai_ft_in1k
# vit_large_patch14_clip_224.openai_ft_in12k
# vit_large_patch14_clip_224.openai_ft_in12k_in1k
# vit_large_patch14_clip_336.laion2b_ft_in1k
# vit_large_patch14_clip_336.laion2b_ft_in12k_in1k
# vit_large_patch14_clip_336.openai
# vit_large_patch14_clip_336.openai_ft_in12k_in1k
# vit_large_patch14_clip_quickgelu_224.dfn2b
# vit_large_patch14_clip_quickgelu_224.metaclip_2pt5b
# vit_large_patch14_clip_quickgelu_224.metaclip_400m
# vit_large_patch14_clip_quickgelu_224.openai
# vit_large_patch14_clip_quickgelu_336.openai
# vit_large_patch14_dinov2.lvd142m
# vit_large_patch14_reg4_dinov2.lvd142m
# vit_large_patch16_224.augreg_in21k
# vit_large_patch16_224.augreg_in21k_ft_in1k
# vit_large_patch16_224.mae
# vit_large_patch16_224.orig_in21k
# vit_large_patch16_384.augreg_in21k_ft_in1k
# vit_large_patch16_siglip_256.v2_webli
# vit_large_patch16_siglip_256.webli
# vit_large_patch16_siglip_384.v2_webli
# vit_large_patch16_siglip_384.webli
# vit_large_patch16_siglip_512.v2_webli
# vit_large_patch16_siglip_gap_256.v2_webli
# vit_large_patch16_siglip_gap_256.webli
# vit_large_patch16_siglip_gap_384.v2_webli
# vit_large_patch16_siglip_gap_384.webli
# vit_large_patch16_siglip_gap_512.v2_webli
# vit_large_patch32_224.orig_in21k
# vit_large_patch32_384.orig_in21k_ft_in1k
# vit_large_r50_s32_224.augreg_in21k
# vit_large_r50_s32_224.augreg_in21k_ft_in1k
# vit_large_r50_s32_384.augreg_in21k_ft_in1k
# vit_little_patch16_reg1_gap_256.sbb_in12k
# vit_little_patch16_reg1_gap_256.sbb_in12k_ft_in1k
# vit_little_patch16_reg4_gap_256.sbb_in1k
# vit_medium_patch16_clip_224.tinyclip_yfcc15m
# vit_medium_patch16_gap_240.sw_in12k
# vit_medium_patch16_gap_256.sw_in12k_ft_in1k
# vit_medium_patch16_gap_384.sw_in12k_ft_in1k
# vit_medium_patch16_reg1_gap_256.sbb_in1k
# vit_medium_patch16_reg4_gap_256.sbb_in1k
# vit_medium_patch16_reg4_gap_256.sbb_in12k
# vit_medium_patch16_reg4_gap_256.sbb_in12k_ft_in1k
# vit_medium_patch16_rope_reg1_gap_256.sbb_in1k
# vit_medium_patch32_clip_224.tinyclip_laion400m
# vit_mediumd_patch16_reg4_gap_256.sbb2_e200_in12k
# vit_mediumd_patch16_reg4_gap_256.sbb2_e200_in12k_ft_in1k
# vit_mediumd_patch16_reg4_gap_256.sbb_in12k
# vit_mediumd_patch16_reg4_gap_256.sbb_in12k_ft_in1k
# vit_mediumd_patch16_reg4_gap_384.sbb2_e200_in12k_ft_in1k
# vit_mediumd_patch16_rope_reg1_gap_256.sbb_in1k
# vit_pwee_patch16_reg1_gap_256.sbb_in1k
# vit_relpos_base_patch16_224.sw_in1k
# vit_relpos_base_patch16_clsgap_224.sw_in1k
# vit_relpos_base_patch32_plus_rpn_256.sw_in1k
# vit_relpos_medium_patch16_224.sw_in1k
# vit_relpos_medium_patch16_cls_224.sw_in1k
# vit_relpos_medium_patch16_rpn_224.sw_in1k
# vit_relpos_small_patch16_224.sw_in1k
# vit_small_patch8_224.dino
# vit_small_patch14_dinov2.lvd142m
# vit_small_patch14_reg4_dinov2.lvd142m
# vit_small_patch16_224.augreg_in1k
# vit_small_patch16_224.augreg_in21k
# vit_small_patch16_224.augreg_in21k_ft_in1k
# vit_small_patch16_224.dino
# vit_small_patch16_384.augreg_in1k
# vit_small_patch16_384.augreg_in21k_ft_in1k
# vit_small_patch32_224.augreg_in21k
# vit_small_patch32_224.augreg_in21k_ft_in1k
# vit_small_patch32_384.augreg_in21k_ft_in1k
# vit_small_r26_s32_224.augreg_in21k
# vit_small_r26_s32_224.augreg_in21k_ft_in1k
# vit_small_r26_s32_384.augreg_in21k_ft_in1k
# vit_so150m2_patch16_reg1_gap_256.sbb_e200_in12k
# vit_so150m2_patch16_reg1_gap_256.sbb_e200_in12k_ft_in1k
# vit_so150m2_patch16_reg1_gap_384.sbb_e200_in12k_ft_in1k
# vit_so150m2_patch16_reg1_gap_448.sbb_e200_in12k_ft_in1k
# vit_so150m_patch16_reg4_gap_256.sbb_e250_in12k
# vit_so150m_patch16_reg4_gap_256.sbb_e250_in12k_ft_in1k
# vit_so150m_patch16_reg4_gap_384.sbb_e250_in12k_ft_in1k
# vit_so400m_patch14_siglip_224.v2_webli
# vit_so400m_patch14_siglip_224.webli
# vit_so400m_patch14_siglip_378.v2_webli
# vit_so400m_patch14_siglip_378.webli
# vit_so400m_patch14_siglip_378.webli_ft_in1k
# vit_so400m_patch14_siglip_384.webli
# vit_so400m_patch14_siglip_gap_224.pali2_3b_pt
# vit_so400m_patch14_siglip_gap_224.pali2_10b_pt
# vit_so400m_patch14_siglip_gap_224.pali_mix
# vit_so400m_patch14_siglip_gap_224.pali_pt
# vit_so400m_patch14_siglip_gap_224.v2_webli
# vit_so400m_patch14_siglip_gap_224.webli
# vit_so400m_patch14_siglip_gap_378.v2_webli
# vit_so400m_patch14_siglip_gap_378.webli
# vit_so400m_patch14_siglip_gap_378.webli_ft_in1k
# vit_so400m_patch14_siglip_gap_384.webli
# vit_so400m_patch14_siglip_gap_448.pali2_3b_docci
# vit_so400m_patch14_siglip_gap_448.pali2_3b_pt
# vit_so400m_patch14_siglip_gap_448.pali2_10b_docci
# vit_so400m_patch14_siglip_gap_448.pali2_10b_pt
# vit_so400m_patch14_siglip_gap_448.pali_mix
# vit_so400m_patch14_siglip_gap_448.pali_ocrvqa
# vit_so400m_patch14_siglip_gap_448.pali_pt
# vit_so400m_patch14_siglip_gap_448.pali_refcoco_seg
# vit_so400m_patch14_siglip_gap_896.pali2_3b_pt
# vit_so400m_patch14_siglip_gap_896.pali2_10b_pt
# vit_so400m_patch14_siglip_gap_896.pali_ocrvqa
# vit_so400m_patch14_siglip_gap_896.pali_pt
# vit_so400m_patch14_siglip_gap_896.pali_refcoco_seg
# vit_so400m_patch16_siglip_256.v2_webli
# vit_so400m_patch16_siglip_256.webli_i18n
# vit_so400m_patch16_siglip_384.v2_webli
# vit_so400m_patch16_siglip_512.v2_webli
# vit_so400m_patch16_siglip_gap_256.v2_webli
# vit_so400m_patch16_siglip_gap_256.webli_i18n
# vit_so400m_patch16_siglip_gap_384.v2_webli
# vit_so400m_patch16_siglip_gap_512.v2_webli
# vit_srelpos_medium_patch16_224.sw_in1k
# vit_srelpos_small_patch16_224.sw_in1k
# vit_tiny_patch16_224.augreg_in21k
# vit_tiny_patch16_224.augreg_in21k_ft_in1k
# vit_tiny_patch16_384.augreg_in21k_ft_in1k
# vit_tiny_r_s16_p8_224.augreg_in21k
# vit_tiny_r_s16_p8_224.augreg_in21k_ft_in1k
# vit_tiny_r_s16_p8_384.augreg_in21k_ft_in1k
# vit_wee_patch16_reg1_gap_256.sbb_in1k
# vit_xsmall_patch16_clip_224.tinyclip_yfcc15m
# vitamin_base_224.datacomp1b_clip
# vitamin_base_224.datacomp1b_clip_ltt
# vitamin_large2_224.datacomp1b_clip
# vitamin_large2_256.datacomp1b_clip
# vitamin_large2_336.datacomp1b_clip
# vitamin_large2_384.datacomp1b_clip
# vitamin_large_224.datacomp1b_clip
# vitamin_large_256.datacomp1b_clip
# vitamin_large_336.datacomp1b_clip
# vitamin_large_384.datacomp1b_clip
# vitamin_small_224.datacomp1b_clip
# vitamin_small_224.datacomp1b_clip_ltt
# vitamin_xlarge_256.datacomp1b_clip
# vitamin_xlarge_336.datacomp1b_clip
# vitamin_xlarge_384.datacomp1b_clip
# volo_d1_224.sail_in1k
# volo_d1_384.sail_in1k
# volo_d2_224.sail_in1k
# volo_d2_384.sail_in1k
# volo_d3_224.sail_in1k
# volo_d3_448.sail_in1k
# volo_d4_224.sail_in1k
# volo_d4_448.sail_in1k
# volo_d5_224.sail_in1k
# volo_d5_448.sail_in1k
# volo_d5_512.sail_in1k
# wide_resnet50_2.racm_in1k
# wide_resnet50_2.tv2_in1k
# wide_resnet50_2.tv_in1k
# wide_resnet101_2.tv2_in1k
# wide_resnet101_2.tv_in1k
# xception41.tf_in1k
# xception41p.ra3_in1k
# xception65.ra3_in1k
# xception65.tf_in1k
# xception65p.ra3_in1k
# xception71.tf_in1k
# xcit_large_24_p8_224.fb_dist_in1k
# xcit_large_24_p8_224.fb_in1k
# xcit_large_24_p8_384.fb_dist_in1k
# xcit_large_24_p16_224.fb_dist_in1k
# xcit_large_24_p16_224.fb_in1k
# xcit_large_24_p16_384.fb_dist_in1k
# xcit_medium_24_p8_224.fb_dist_in1k
# xcit_medium_24_p8_224.fb_in1k
# xcit_medium_24_p8_384.fb_dist_in1k
# xcit_medium_24_p16_224.fb_dist_in1k
# xcit_medium_24_p16_224.fb_in1k
# xcit_medium_24_p16_384.fb_dist_in1k
# xcit_nano_12_p8_224.fb_dist_in1k
# xcit_nano_12_p8_224.fb_in1k
# xcit_nano_12_p8_384.fb_dist_in1k
# xcit_nano_12_p16_224.fb_dist_in1k
# xcit_nano_12_p16_224.fb_in1k
# xcit_nano_12_p16_384.fb_dist_in1k
# xcit_small_12_p8_224.fb_dist_in1k
# xcit_small_12_p8_224.fb_in1k
# xcit_small_12_p8_384.fb_dist_in1k
# xcit_small_12_p16_224.fb_dist_in1k
# xcit_small_12_p16_224.fb_in1k
# xcit_small_12_p16_384.fb_dist_in1k
# xcit_small_24_p8_224.fb_dist_in1k
# xcit_small_24_p8_224.fb_in1k
# xcit_small_24_p8_384.fb_dist_in1k
# xcit_small_24_p16_224.fb_dist_in1k
# xcit_small_24_p16_224.fb_in1k
# xcit_small_24_p16_384.fb_dist_in1k
# xcit_tiny_12_p8_224.fb_dist_in1k
# xcit_tiny_12_p8_224.fb_in1k
# xcit_tiny_12_p8_384.fb_dist_in1k
# xcit_tiny_12_p16_224.fb_dist_in1k
# xcit_tiny_12_p16_224.fb_in1k
# xcit_tiny_12_p16_384.fb_dist_in1k
# xcit_tiny_24_p8_224.fb_dist_in1k
# xcit_tiny_24_p8_224.fb_in1k
# xcit_tiny_24_p8_384.fb_dist_in1k
# xcit_tiny_24_p16_224.fb_dist_in1k
# xcit_tiny_24_p16_224.fb_in1k
# xcit_tiny_24_p16_384.fb_dist_in1k

# %%
# Create Dataset class for multilabel classification
class MultiClassImageDataset(Dataset):
    def __init__(self, ann_df, super_map_df, sub_map_df, img_dir, transform=None):
        self.ann_df = ann_df
        self.super_map_df = super_map_df
        self.sub_map_df = sub_map_df
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.ann_df)

    def __getitem__(self, idx):
        img_name = self.ann_df['image'][idx]
        img_path = os.path.join(self.img_dir, img_name)
        image = Image.open(img_path).convert('RGB')

        super_idx = self.ann_df['superclass_index'][idx]
        super_label = self.super_map_df['class'][super_idx]

        sub_idx = self.ann_df['subclass_index'][idx]
        sub_label = self.sub_map_df['class'][sub_idx]

        if self.transform:
            image = self.transform(image)

        return image, super_idx, super_label, sub_idx, sub_label

class MultiClassImageTestDataset(Dataset):
    def __init__(self, super_map_df, sub_map_df, img_dir, transform=None):
        self.super_map_df = super_map_df
        self.sub_map_df = sub_map_df
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self): # Count files in img_dir
        return len([fname for fname in os.listdir(self.img_dir)])

    def __getitem__(self, idx):
        img_name = str(idx) + '.jpg'
        img_path = os.path.join(self.img_dir, img_name)
        image = Image.open(img_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, img_name

# %%
train_ann_df = pd.read_csv('Released_Data_NNDL_2025/train_data.csv')
super_map_df = pd.read_csv('Released_Data_NNDL_2025/superclass_mapping.csv')
sub_map_df = pd.read_csv('Released_Data_NNDL_2025/subclass_mapping.csv')

train_img_dir = 'train_images'
test_img_dir = 'test_images'

timm_model_name = 'convnextv2_huge.fcmae_ft_in22k_in1k_384'

convnext_model = timm.create_model(timm_model_name, pretrained=True, num_classes=0)
convnext_data_config = timm.data.resolve_model_data_config(convnext_model)
convnext_transforms = timm.data.create_transform(**convnext_data_config, is_training=False)

last_layer_nodes = convnext_model.num_features
print(last_layer_nodes)

del convnext_model

# image_preprocessing = transforms.Compose([
#     transforms.ToTensor(),
#     transforms.Normalize(mean=(0), std=(1)),
# ])

# Create train and val split
train_dataset = MultiClassImageDataset(train_ann_df, super_map_df, sub_map_df, train_img_dir, transform=convnext_transforms)
train_dataset, val_dataset = random_split(train_dataset, [0.9, 0.1])

# Create test dataset
test_dataset = MultiClassImageTestDataset(super_map_df, sub_map_df, test_img_dir, transform=convnext_transforms)

# Create dataloaders
batch_size = 16
train_loader = DataLoader(train_dataset,
                          batch_size=batch_size,
                          shuffle=True)

val_loader = DataLoader(val_dataset,
                        batch_size=batch_size,
                        shuffle=True)

test_loader = DataLoader(test_dataset,
                         batch_size=1,
                         shuffle=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/2.64G [00:00<?, ?B/s]
# 2816

# %%
class GeneralModel(nn.Module):
    def __init__(self, freeze_main=True):
        super().__init__()

        self.freeze_main = freeze_main

        self.main_model = timm.create_model(timm_model_name, pretrained=True, num_classes=0)
        self.main_model.eval()

        self.super_fc = nn.Linear(last_layer_nodes, 4)
        self.sub_fc = nn.Linear(last_layer_nodes, 88)

    def forward(self, x):
        if self.freeze_main == True:
            with torch.no_grad():
                x = self.main_model(x)
        else:
                x = self.main_model(x)

        super_out = self.super_fc(x)
        sub_out = self.sub_fc(x)

        return super_out, sub_out

class Trainer():
    def __init__(self, model, criterion, optimizer, train_loader, val_loader, test_loader=None, device='cuda'):
        self.model = model
        self.criterion = criterion
        self.optimizer = optimizer
        self.train_loader = train_loader
        self.val_loader = val_loader
        self.test_loader = test_loader

    def train_epoch(self):
        running_loss = 0.0
        for i, data in tqdm(enumerate(self.train_loader), total=len(self.train_loader)):
            inputs, super_labels, sub_labels = data[0].to(device), data[1].to(device), data[3].to(device)

            self.optimizer.zero_grad()
            super_outputs, sub_outputs = self.model(inputs)
            loss = self.criterion(super_outputs, super_labels) + self.criterion(sub_outputs, sub_labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        print(f'Training loss: {running_loss/i:.3f}')

    def validate_epoch(self):
        super_correct = 0
        sub_correct = 0
        total = 0
        running_loss = 0.0
        with torch.no_grad():
            for i, data in tqdm(enumerate(self.val_loader), total=len(self.val_loader)):
                inputs, super_labels, sub_labels = data[0].to(device), data[1].to(device), data[3].to(device)

                super_outputs, sub_outputs = self.model(inputs)
                loss = self.criterion(super_outputs, super_labels) + self.criterion(sub_outputs, sub_labels)
                _, super_predicted = torch.max(super_outputs.data, 1)
                _, sub_predicted = torch.max(sub_outputs.data, 1)

                total += super_labels.size(0)
                super_correct += (super_predicted == super_labels).sum().item()
                sub_correct += (sub_predicted == sub_labels).sum().item()
                running_loss += loss.item()

        print(f'Validation loss: {running_loss/i:.3f}')
        print(f'Validation superclass acc: {100 * super_correct / total:.2f} %')
        print(f'Validation subclass acc: {100 * sub_correct / total:.2f} %')

    def test(self, save_to_csv=False, return_predictions=False):
        if not self.test_loader:
            raise NotImplementedError('test_loader not specified')

        # Evaluate on test set, in this simple demo no special care is taken for novel/unseen classes
        test_predictions = {'image': [], 'superclass_index': [], 'subclass_index': []}
        with torch.no_grad():
            for i, data in tqdm(enumerate(self.test_loader), total=len(self.test_loader)):
                inputs, img_name = data[0].to(device), data[1]

                super_outputs, sub_outputs = self.model(inputs)
                _, super_predicted = torch.max(super_outputs.data, 1)
                _, sub_predicted = torch.max(sub_outputs.data, 1)

                test_predictions['image'].append(img_name[0])
                test_predictions['superclass_index'].append(super_predicted.item())
                test_predictions['subclass_index'].append(sub_predicted.item())

        test_predictions = pd.DataFrame(data=test_predictions)

        if save_to_csv:
            current_time = datetime.now().strftime("%Y-%m-%d-%H-%M-%S")
            if not os.path.exists(current_time):
                os.mkdir(current_time)
            test_predictions.to_csv(current_time + '/test_predictions.csv', index=False)

        if return_predictions:
            return test_predictions

# %%
# Init model and trainer
device = 'cuda'
model = GeneralModel()
# model.load_state_dict(torch.load('convnext_model_final.pt', weights_only=True))
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-4)
trainer = Trainer(model, criterion, optimizer, train_loader, val_loader, test_loader)

# %%
# Training loop
for epoch in range(5):
    print(f'Epoch {epoch+1}')
    trainer.train_epoch()
    trainer.validate_epoch()
    print('')

print('Finished Training')
# Out:
# Epoch 1
# 100%|██████████| 354/354 [04:20<00:00,  1.36it/s]
# Training loss: 0.436
# 100%|██████████| 40/40 [00:28<00:00,  1.39it/s]
# Validation loss: 0.197
# Validation superclass acc: 100.00 %
# Validation subclass acc: 94.11 %
#
# Epoch 2
# 100%|██████████| 354/354 [04:19<00:00,  1.36it/s]
# Training loss: 0.088
# 100%|██████████| 40/40 [00:28<00:00,  1.39it/s]
# Validation loss: 0.170
# Validation superclass acc: 100.00 %
# Validation subclass acc: 94.90 %
#
# Epoch 3
# 100%|██████████| 354/354 [04:19<00:00,  1.36it/s]
# Training loss: 0.053
# 100%|██████████| 40/40 [00:28<00:00,  1.39it/s]
# Validation loss: 0.100
# Validation superclass acc: 100.00 %
# Validation subclass acc: 96.97 %
#
# Epoch 4
# 100%|██████████| 354/354 [04:19<00:00,  1.36it/s]
# Training loss: 0.034
# 100%|██████████| 40/40 [00:28<00:00,  1.39it/s]
# Validation loss: 0.123
# Validation superclass acc: 100.00 %
# Validation subclass acc: 96.50 %
#
# Epoch 5
# 100%|██████████| 354/354 [04:19<00:00,  1.36it/s]
# Training loss: 0.038
# 100%|██████████| 40/40 [00:28<00:00,  1.39it/s]
# Validation loss: 0.139
# Validation superclass acc: 100.00 %
# Validation subclass acc: 95.86 %
#
# Finished Training

# %%
torch.save(model.state_dict(), 'convnext_model_final.pt')

# %%
test_predictions = trainer.test(save_to_csv=True, return_predictions=True)
# Out:
# 100%|██████████| 11180/11180 [10:23<00:00, 17.92it/s]

# %%
# validation with collecting of prob scores to help with deciding threshold
super_correct = 0
sub_correct = 0
total = 0
running_loss = 0.

super_all_scores = []
sub_all_scores = []

super_all_energies = []
sub_all_energies = []

with torch.no_grad():
    for i, data in tqdm(enumerate(trainer.val_loader), total=len(trainer.val_loader)):
        inputs, super_labels, sub_labels = data[0].to(device), data[1].to(device), data[3].to(device)

        super_outputs, sub_outputs = trainer.model(inputs)
        loss = trainer.criterion(super_outputs, super_labels) + trainer.criterion(sub_outputs, sub_labels)
        _, super_predicted = torch.max(super_outputs.data, 1)
        _, sub_predicted = torch.max(sub_outputs.data, 1)

        super_probs = torch.nn.functional.softmax(super_outputs.data, 1)
        sub_probs = torch.nn.functional.softmax(sub_outputs.data, 1)

        super_scores, _ = torch.max(super_probs, 1)
        sub_scores, _ = torch.max(sub_probs, 1)

        super_energies = -torch.logsumexp(super_outputs.data, dim=1)
        sub_energies = -torch.logsumexp(sub_outputs.data, dim=1)

        super_all_scores.extend(super_scores.tolist())
        sub_all_scores.extend(sub_scores.tolist())

        super_all_energies.extend(super_energies.tolist())
        sub_all_energies.extend(sub_energies.tolist())

        total += super_labels.size(0)
        super_correct += (super_predicted == super_labels).sum().item()
        sub_correct += (sub_predicted == sub_labels).sum().item()
        running_loss += loss.item()

print(f'Validation loss: {running_loss/i:.3f}')
print(f'Validation superclass acc: {100 * super_correct / total:.2f} %')
print(f'Validation subclass acc: {100 * sub_correct / total:.2f} %')
# Out:
# 100%|██████████| 40/40 [00:29<00:00,  1.38it/s]
# Validation loss: 0.139
# Validation superclass acc: 100.00 %
# Validation subclass acc: 95.86 %

# %%
display(pd.DataFrame(super_all_scores).describe())
display(pd.DataFrame(sub_all_scores).describe())
# Out:
#                 0
# count  628.000000
# mean     0.999940
# std      0.000296
# min      0.993611
# 25%      0.999968
# 50%      0.999994
# 75%      0.999999
# max      1.000000
#                 0
# count  628.000000
# mean     0.987351
# std      0.056163
# min      0.429258
# 25%      0.999165
# 50%      0.999879
# 75%      0.999975
# max      1.000000

# %%
display(pd.DataFrame(super_all_energies).describe())
display(pd.DataFrame(sub_all_energies).describe())
# Out:
#                 0
# count  628.000000
# mean    -9.146938
# std      1.785976
# min    -14.689650
# 25%    -10.299514
# 50%     -9.022823
# 75%     -7.847642
# max     -4.207986
#                 0
# count  628.000000
# mean   -12.245291
# std      3.007796
# min    -23.391033
# 25%    -13.705450
# 50%    -11.888737
# 75%    -10.219782
# max     -4.362776

# %%
super_score_threshold = float(np.mean(super_all_scores) - 3 * np.std(super_all_scores))
sub_score_threshold = float(np.mean(sub_all_scores) - 3 * np.std(sub_all_scores))

print(super_score_threshold)
print(sub_score_threshold)
# Out:
# 0.9990530562800088
# 0.8189966143347298

# %%
super_energy_threshold = float(np.mean(super_all_energies) - 3 * np.std(super_all_energies))
sub_energy_threshold = float(np.mean(sub_all_energies) - 3 * np.std(sub_all_energies))

print(super_energy_threshold)
print(sub_energy_threshold)
# Out:
# -14.50059670341956
# -21.261492462608906

# %%
# with chosen thresholds, make novel OOD decisions as well using softmax scores
test_predictions = {'image': [], 'superclass_index': [], 'subclass_index': []}
with torch.no_grad():
    for i, data in tqdm(enumerate(trainer.test_loader), total=len(trainer.test_loader)):
        inputs, img_name = data[0].to(device), data[1]

        super_outputs, sub_outputs = trainer.model(inputs)
        _, super_predicted = torch.max(super_outputs.data, 1)
        _, sub_predicted = torch.max(sub_outputs.data, 1)

        super_probs = torch.nn.functional.softmax(super_outputs.data, 1)
        sub_probs = torch.nn.functional.softmax(sub_outputs.data, 1)

        super_scores, _ = torch.max(super_probs, 1)
        sub_scores, _ = torch.max(sub_probs, 1)

        super_energies = -torch.logsumexp(super_outputs.data, dim=1)
        sub_energies = -torch.logsumexp(sub_outputs.data, dim=1)

        super_predicted = torch.where(super_scores < super_score_threshold,
                                      torch.tensor(3, device=super_predicted.device),
                                      super_predicted)
        sub_predicted = torch.where(sub_scores < sub_score_threshold,
                                    torch.tensor(87, device=sub_predicted.device),
                                    sub_predicted)

        test_predictions['image'].append(img_name[0])
        test_predictions['superclass_index'].append(super_predicted.item())
        test_predictions['subclass_index'].append(sub_predicted.item())

test_predictions = pd.DataFrame(data=test_predictions)

current_time = datetime.now().strftime("%Y-%m-%d-%H-%M-%S")
if not os.path.exists(current_time):
    os.mkdir(current_time)
test_predictions.to_csv(current_time + '/test_predictions.csv', index=False)
# Out:
# 100%|██████████| 11180/11180 [10:25<00:00, 17.88it/s]

# %%
# with chosen thresholds, make novel OOD decisions as well using energies
test_predictions = {'image': [], 'superclass_index': [], 'subclass_index': []}
with torch.no_grad():
    for i, data in tqdm(enumerate(trainer.test_loader), total=len(trainer.test_loader)):
        inputs, img_name = data[0].to(device), data[1]

        super_outputs, sub_outputs = trainer.model(inputs)
        _, super_predicted = torch.max(super_outputs.data, 1)
        _, sub_predicted = torch.max(sub_outputs.data, 1)

        super_probs = torch.nn.functional.softmax(super_outputs.data, 1)
        sub_probs = torch.nn.functional.softmax(sub_outputs.data, 1)

        super_scores, _ = torch.max(super_probs, 1)
        sub_scores, _ = torch.max(sub_probs, 1)

        super_energies = -torch.logsumexp(super_outputs.data, dim=1)
        sub_energies = -torch.logsumexp(sub_outputs.data, dim=1)

        super_predicted = torch.where(super_energies < super_energy_threshold,
                                      torch.tensor(3, device=super_predicted.device),
                                      super_predicted)
        sub_predicted = torch.where(sub_energies < sub_energy_threshold,
                                    torch.tensor(87, device=sub_predicted.device),
                                    sub_predicted)

        test_predictions['image'].append(img_name[0])
        test_predictions['superclass_index'].append(super_predicted.item())
        test_predictions['subclass_index'].append(sub_predicted.item())

test_predictions = pd.DataFrame(data=test_predictions)

current_time = datetime.now().strftime("%Y-%m-%d-%H-%M-%S")
if not os.path.exists(current_time):
    os.mkdir(current_time)
test_predictions.to_csv(current_time + '/test_predictions.csv', index=False)
# Out:
# 100%|██████████| 11180/11180 [10:25<00:00, 17.86it/s]

# %%
# with handcoded manual thresholds, make novel OOD decisions as well using softmax scores
test_predictions = {'image': [], 'superclass_index': [], 'subclass_index': []}
with torch.no_grad():
    for i, data in tqdm(enumerate(trainer.test_loader), total=len(trainer.test_loader)):
        inputs, img_name = data[0].to(device), data[1]

        super_outputs, sub_outputs = trainer.model(inputs)
        _, super_predicted = torch.max(super_outputs.data, 1)
        _, sub_predicted = torch.max(sub_outputs.data, 1)

        super_probs = torch.nn.functional.softmax(super_outputs.data, 1)
        sub_probs = torch.nn.functional.softmax(sub_outputs.data, 1)

        super_scores, _ = torch.max(super_probs, 1)
        sub_scores, _ = torch.max(sub_probs, 1)

        super_energies = -torch.logsumexp(super_outputs.data, dim=1)
        sub_energies = -torch.logsumexp(sub_outputs.data, dim=1)

        super_predicted = torch.where(super_scores < 0.95,
                                      torch.tensor(3, device=super_predicted.device),
                                      super_predicted)
        sub_predicted = torch.where(sub_scores < 0.75,
                                    torch.tensor(87, device=sub_predicted.device),
                                    sub_predicted)

        test_predictions['image'].append(img_name[0])
        test_predictions['superclass_index'].append(super_predicted.item())
        test_predictions['subclass_index'].append(sub_predicted.item())

test_predictions = pd.DataFrame(data=test_predictions)

current_time = datetime.now().strftime("%Y-%m-%d-%H-%M-%S")
if not os.path.exists(current_time):
    os.mkdir(current_time)
test_predictions.to_csv(current_time + '/test_predictions.csv', index=False)
# Out:
# 100%|██████████| 11180/11180 [10:25<00:00, 17.88it/s]
